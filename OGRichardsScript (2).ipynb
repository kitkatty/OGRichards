# %%
#credits to @Wolfram_eth for https://raw.githubusercontent.com/mtxjwo/bookofrichard/main/richards

# %%
pip install web3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 500 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 101 kB 10.5 MB/s
# ...
#      |████████████████████████████████| 103 kB 61.1 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 53.1 MB/s
# ...
#      |████████████████████████████████| 82 kB 858 kB/s
# ...
#      |████████████████████████████████| 94 kB 3.1 MB/s
# ...
#      |████████████████████████████████| 271 kB 57.9 MB/s
# ...
#      |████████████████████████████████| 144 kB 53.7 MB/s
# ...
#      |████████████████████████████████| 45 kB 3.0 MB/s
# ...
#      |████████████████████████████████| 236 kB 55.4 MB/s
# ...
#      |████████████████████████████████| 2.3 MB 38.5 MB/s
# ...
#      |████████████████████████████████| 481 kB 50.8 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 49.3 MB/s
# ...

# %%
from web3 import Web3

provider_url = 'https://mainnet.infura.io/v3/4900796adf62449f9d9f5c488dd53346'

w3 = Web3(Web3.HTTPProvider(provider_url))

# %%
w3.isConnected()
# Out:
# True

# %%
from ens import ENS

w3 = Web3(Web3.HTTPProvider(provider_url))
ns = ENS.fromWeb3(w3)

# %%
eth1=	ns.address('richard47.eth')
eth2=	ns.address('richardcooper.eth')
eth3=	ns.address('69richard.eth')
eth4=	ns.address('richardryan.eth')
eth5=	ns.address('richard508.eth')
eth6=	ns.address('richardchi.eth')
eth7=	ns.address('richard555.eth')
eth8=	ns.address('richardderivative.eth')
eth9=	ns.address('richard-mutt.eth')
eth10=	ns.address('defirichard.eth')
eth11=	ns.address('🤴richard.eth')
eth12=	ns.address('arichardlaurent.eth')
eth13=	ns.address('keithrichards.eth')
eth14=	ns.address('richardcomedy.eth')
eth15=	ns.address('richardrui.eth')
eth16=	ns.address('richard400.eth')
eth17=	ns.address('micahrichards.eth')
eth18=	ns.address('princerichard.eth')
eth19=	ns.address('richardface.eth')
eth20=	ns.address('richarddixon.eth')
eth21=	ns.address('richard®.eth')
eth22=	ns.address('richardrichard.eth')
eth23=	ns.address('richardpix.eth')
eth24=	ns.address('chrisrichardson.eth')
eth25=	ns.address('richardwiig.eth')
eth26=	ns.address('richardent.eth')
eth27=	ns.address('mrsrichard.eth')
eth28=	ns.address('richardwatkins.eth')
eth29=	ns.address('richardman.eth')
eth30=	ns.address('not-richard.eth')
eth31=	ns.address('richard113.eth')
eth32=	ns.address('richard28.eth')
eth33=	ns.address('richarddebas.eth')
eth34=	ns.address('giverichard.eth')
eth35=	ns.address('davidrichardson.eth')
eth36=	ns.address('hairyrichard.eth')
eth37=	ns.address('firstrichard.eth')
eth38=	ns.address('richard68.eth')
eth39=	ns.address('xrichardx.eth')
eth40=	ns.address('richardsons.eth')
eth41=	ns.address('richard925.eth')
eth42=	ns.address('richard87.eth')
eth43=	ns.address('richardmolloy.eth')
eth44=	ns.address('richardmille3502.eth')
eth45=	ns.address('papirichard.eth')
eth46=	ns.address('richardslezak.eth')
eth47=	ns.address('richard15.eth')
eth48=	ns.address('0xrichard11.eth')
eth49=	ns.address('richardgear.eth')
eth50=	ns.address('easyrichard.eth')
eth51=	ns.address('0xrichard.eth')
eth52=	ns.address('ogrichard.eth')
eth53=	ns.address('0xkingrichard.eth')
eth54=	ns.address('richard110.eth')
eth55=	ns.address('filthyrichard.eth')
eth56=	ns.address('sarahrichards.eth')
eth57=	ns.address('richard7.eth')
eth58=	ns.address('stop-richarding.eth')
eth59=	ns.address('richardbuu.eth')
eth60=	ns.address('richardfinity.eth')
eth61=	ns.address('richardu.eth')
eth62=	ns.address('richardgiles.eth')
eth63=	ns.address('richard-dao.eth')
eth64=	ns.address('bedroomrichard.eth')
eth65=	ns.address('skylarrichard.eth')
eth66=	ns.address('litlerichard.eth')
eth67=	ns.address('richard916.eth')
eth68=	ns.address('richardyolo.eth')
eth69=	ns.address('cbrichardellis.eth')
eth70=	ns.address('rentarichard.eth')
eth71=	ns.address('jamesrichardfry.eth')
eth72=	ns.address('thelastrichard.eth')
eth73=	ns.address('sendrichard.eth')
eth74=	ns.address('richardprints.eth')
eth75=	ns.address('richardsprague.eth')
eth76=	ns.address('richardisme.eth')
eth77=	ns.address('richard16.eth')
eth78=	ns.address('totalrichard.eth')
eth79=	ns.address('paulrichards.eth')
eth80=	ns.address('zkrichard.eth')
eth81=	ns.address('richard120.eth')
eth82=	ns.address('steverichards.eth')
eth83=	ns.address('sirrichardstarkeymberingostarr.eth')
eth84=	ns.address('richardgarriott.eth')
eth85=	ns.address('sirrichard.eth')
eth86=	ns.address('richardlim.eth')
eth87=	ns.address('richardliang.eth')
eth88=	ns.address('richardgang.eth')
eth89=	ns.address('richardfang.eth')
eth90=	ns.address('whenrichardheartonbankless.eth')
eth91=	ns.address('richardzphotoz.eth')
eth92=	ns.address('ezrichard.eth')
eth93=	ns.address('richardgarcia.eth')
eth94=	ns.address('adamrichard.eth')
eth95=	ns.address('richardgm.eth')
eth96=	ns.address('richard91.eth')
eth97=	ns.address('richardg.eth')
eth98=	ns.address('richardcapital.eth')
eth99=	ns.address('richard70.eth')
eth100=	ns.address('richardsburgers.eth')
eth101=	ns.address('richardma.eth')
eth102=	ns.address('richard2023.eth')
eth103=	ns.address('richard999.eth')
eth104=	ns.address('richard12.eth')
eth105=	ns.address('bigrichardenergy.eth')
eth106=	ns.address('richardtran.eth')
eth107=	ns.address('richardcheese.eth')
eth108=	ns.address('richierichard.eth')
eth109=	ns.address('richardgothits.eth')
eth110=	ns.address('richardtrickle.eth')
eth111=	ns.address('peperichard.eth')
eth112=	ns.address('richard102.eth')
eth113=	ns.address('goodrichard.eth')
eth114=	ns.address('richard-petty.eth')
eth115=	ns.address('richard19.eth')
eth116=	ns.address('richard26.eth')
eth117=	ns.address('degenrichard.eth')
eth118=	ns.address('jordanrichardson.eth')
eth119=	ns.address('richard02.eth')
eth120=	ns.address('makerichardgreatagain.eth')
eth121=	ns.address('richard500.eth')
eth122=	ns.address('richardalpert.eth')
eth123=	ns.address('no1richard.eth')
eth124=	ns.address('richardvandyke.eth')
eth125=	ns.address('richard914.eth')
eth126=	ns.address('whatthefuckrichard.eth')
eth127=	ns.address('cuckrichard.eth')
eth128=	ns.address('largerichard.eth')
eth129=	ns.address('spottedrichard.eth')
eth130=	ns.address('poorrichard.eth')
eth131=	ns.address('richardsonroyer.eth')
eth132=	ns.address('whiterichard.eth')
eth133=	ns.address('richardeddown.eth')
eth134=	ns.address('richardrosa.eth')
eth135=	ns.address('eatarichard.eth')
eth136=	ns.address('mommarichard.eth')
eth137=	ns.address('richard561.eth')
eth138=	ns.address('richardwagner.eth')
eth139=	ns.address('hardrichard.eth')
eth140=	ns.address('howrichard.eth')
eth141=	ns.address('richardson420.eth')
eth142=	ns.address('mrichard.eth')
eth143=	ns.address('richardcon.eth')
eth144=	ns.address('richardsimmons.eth')
eth145=	ns.address('richardvip.eth')
eth146=	ns.address('richardbertozzo.eth')
eth147=	ns.address('thankyourichard.eth')
eth148=	ns.address('richardgarner.eth')
eth149=	ns.address('richard747.eth')
eth150=	ns.address('jasonrrichardson.eth')
eth151=	ns.address('richard312.eth')
eth152=	ns.address('richardgov.eth')
eth153=	ns.address('hallofrichard.eth')
eth154=	ns.address('richrichard.eth')
eth155=	ns.address('richardmaris.eth')
eth156=	ns.address('richardless.eth')
eth157=	ns.address('richardbaker.eth')
eth158=	ns.address('ourrichard.eth')
eth159=	ns.address('richardxxx.eth')
eth160=	ns.address('i-richard.eth')
eth161=	ns.address('richard⚡.eth')
eth162=	ns.address('richard03.eth')
eth163=	ns.address('richardblevins.eth')
eth164=	ns.address('richard011.eth')
eth165=	ns.address('richardlicker.eth')
eth166=	ns.address('richard502.eth')
eth167=	ns.address('richarduy.eth')
eth168=	ns.address('richardjokes.eth')
eth169=	ns.address('slaprichard.eth')
eth170=	ns.address('richardrich.eth')
eth171=	ns.address('kevinrichardson.eth')
eth172=	ns.address('richard-bot.eth')
eth173=	ns.address('richardtracy.eth')
eth174=	ns.address('jprichardson.eth')
eth175=	ns.address('mrrichard.eth')
eth176=	ns.address('richard55.eth')
eth177=	ns.address('sithrichard.eth')
eth178=	ns.address('richardescobar.eth')
eth179=	ns.address('richardpay.eth')
eth180=	ns.address('richardwood.eth')
eth181=	ns.address('richardpicart.eth')
eth182=	ns.address('kylerichards.eth')
eth183=	ns.address('richardle.eth')
eth184=	ns.address('richardsimpson.eth')
eth185=	ns.address('richardjypark.eth')
eth186=	ns.address('rich-richer-richard.eth')
eth187=	ns.address('richard646.eth')
eth188=	ns.address('richardgod.eth')
eth189=	ns.address('richardmill.eth')
eth190=	ns.address('richarduranus.eth')
eth191=	ns.address('chickswithrichards.eth')
eth192=	ns.address('richarddjames.eth')
eth193=	ns.address('serrichard.eth')
eth194=	ns.address('otherrichard.eth')
eth195=	ns.address('wereallrichard.eth')
eth196=	ns.address('richardisgay.eth')
eth197=	ns.address('richardhendrix.eth')
eth198=	ns.address('richard504.eth')
eth199=	ns.address('richard62.eth')
eth200=	ns.address('richard27.eth')
eth201=	ns.address('richardcheung.eth')
eth202=	ns.address('richard31.eth')
eth203=	ns.address('jamesrichardson.eth')
eth204=	ns.address('gotrichard.eth')
eth205=	ns.address('richardhard.eth')
eth206=	ns.address('richarde.eth')
eth207=	ns.address('richardjkunz.eth')
eth208=	ns.address('richardb.eth')
eth209=	ns.address('richardshan.eth')
eth210=	ns.address('samrichards.eth')
eth211=	ns.address('richardbot.eth')
eth212=	ns.address('richard75.eth')
eth213=	ns.address('chadrichard.eth')
eth214=	ns.address('richardoh.eth')
eth215=	ns.address('richard42.eth')
eth216=	ns.address('dukerichard.eth')
eth217=	ns.address('richardroche.eth')
eth218=	ns.address('richard125.eth')
eth219=	ns.address('anti-richard.eth')
eth220=	ns.address('keithrichard.eth')
eth221=	ns.address('mr-richard.eth')
eth222=	ns.address('richardricardo.eth')
eth223=	ns.address('richard333.eth')
eth224=	ns.address('richard25.eth')
eth225=	ns.address('richardlee.eth')
eth226=	ns.address('berichard.eth')
eth227=	ns.address('richard917.eth')
eth228=	ns.address('richardhomer.eth')
eth229=	ns.address('richardaf.eth')
eth230=	ns.address('pimprichard.eth')
eth231=	ns.address('richard509.eth')
eth232=	ns.address('richardnoggin.eth')
eth233=	ns.address('richardsmom.eth')
eth234=	ns.address('therichards.eth')
eth235=	ns.address('joerichard.eth')
eth236=	ns.address('prichard.eth')
eth237=	ns.address('richardasfuck.eth')
eth238=	ns.address('richardyu.eth')
eth239=	ns.address('richard107.eth')
eth240=	ns.address('richard06.eth')
eth241=	ns.address('richard11.eth')
eth242=	ns.address('richardjpeg.eth')
eth243=	ns.address('richard71.eth')
eth244=	ns.address('richard777.eth')
eth245=	ns.address('richardball.eth')
eth246=	ns.address('richardsen.eth')
eth247=	ns.address('richardette.eth')
eth248=	ns.address('richard202.eth')
eth249=	ns.address('richard8.eth')
eth250=	ns.address('little-richard.eth')
eth251=	ns.address('wenrichard.eth')
eth252=	ns.address('richardick.eth')
eth253=	ns.address('richardandmorty.eth')
eth254=	ns.address('richardbuettner.eth')
eth255=	ns.address('richard51.eth')
eth256=	ns.address('picklerichard.eth')
eth257=	ns.address('richard👑.eth')
eth258=	ns.address('richardgage911.eth')
eth259=	ns.address('richardmille-official.eth')
eth260=	ns.address('richestrichard.eth')
eth261=	ns.address('richardinu.eth')
eth262=	ns.address('richardkelley.eth')
eth263=	ns.address('megarichard.eth')
eth264=	ns.address('🧟‍♂richard.eth')
eth265=	ns.address('richardcheney.eth')
eth266=	ns.address('richardavery.eth')
eth267=	ns.address('richardsanchez.eth')
eth268=	ns.address('richardorlinski.eth')
eth269=	ns.address('richardsenior.eth')
eth270=	ns.address('jackrichardson.eth')
eth271=	ns.address('richardbuterin.eth')
eth272=	ns.address('richardmuljadi.eth')
eth273=	ns.address('johnrichards.eth')
eth274=	ns.address('richardsaghian.eth')
eth275=	ns.address('kidrichard.eth')
eth276=	ns.address('richardlindsay.eth')
eth277=	ns.address('rrrichard.eth')
eth278=	ns.address('babyrichard.eth')
eth279=	ns.address('dickrichard.eth')
eth280=	ns.address('richard🦁🫀.eth')
eth281=	ns.address('clubrichard.eth')
eth282=	ns.address('discordrichard.eth')
eth283=	ns.address('richardmutt.eth')
eth284=	ns.address('richardpaul.eth')
eth285=	ns.address('richardblue.eth')
eth286=	ns.address('richardlovelace.eth')
eth287=	ns.address('richardology.eth')
eth288=	ns.address('richardlewis.eth')
eth289=	ns.address('richardverse.eth')
eth290=	ns.address('richardlevin.eth')
eth291=	ns.address('richard0.eth')
eth292=	ns.address('richardnoun.eth')
eth293=	ns.address('longhardrichard.eth')
eth294=	ns.address('richardn.eth')
eth295=	ns.address('richard808.eth')
eth296=	ns.address('richardx.eth')
eth297=	ns.address('richardbtc.eth')
eth298=	ns.address('richarda.eth')
eth299=	ns.address('richardxhe.eth')
eth300=	ns.address('mrichards.eth')
eth301=	ns.address('richardinya.eth')
eth302=	ns.address('richardtaylor.eth')
eth303=	ns.address('richardhadlee.eth')
eth304=	ns.address('regular-richard.eth')
eth305=	ns.address('richardwallet.eth')
eth306=	ns.address('richard124.eth')
eth307=	ns.address('richardegrant.eth')
eth308=	ns.address('richard2.eth')
eth309=	ns.address('cliffrichard.eth')
eth310=	ns.address('richardwolf.eth')
eth311=	ns.address('richardkim.eth')
eth312=	ns.address('irichard.eth')
eth313=	ns.address('richardvagner.eth')
eth314=	ns.address('richard2022.eth')
eth315=	ns.address('richardrock.eth')
eth316=	ns.address('richard40.eth')
eth317=	ns.address('richardbspencer.eth')
eth318=	ns.address('richardsweat.eth')
eth319=	ns.address('pernod-richard.eth')
eth320=	ns.address('richardoostra.eth')
eth321=	ns.address('richardcrookes.eth')
eth322=	ns.address('richardrauser.eth')
eth323=	ns.address('1-richard.eth')
eth324=	ns.address('richardgere.eth')
eth325=	ns.address('richardanderson.eth')
eth326=	ns.address('richardtodosichuk.eth')
eth327=	ns.address('richardisgod.eth')
eth328=	ns.address('richarddawkins.eth')
eth329=	ns.address('richardpics.eth')
eth330=	ns.address('richardofeth.eth')
eth331=	ns.address('jaredrichardson.eth')
eth332=	ns.address('richardsullivan.eth')
eth333=	ns.address('richardtravis.eth')
eth334=	ns.address('richardmiranda.eth')
eth335=	ns.address('blakerichardson.eth')
eth336=	ns.address('presidentrichardnixon.eth')
eth337=	ns.address('richardnguyen.eth')
eth338=	ns.address('richard56.eth')
eth339=	ns.address('thesearenottherichardsyouarelookingfor.eth')
eth340=	ns.address('richardmnixon.eth')
eth341=	ns.address('ceorichard.eth')
eth342=	ns.address('richardcrypto.eth')
eth343=	ns.address('richardesque.eth')
eth344=	ns.address('fuckyourichard.eth')
eth345=	ns.address('richardsucks.eth')
eth346=	ns.address('richardnixon.eth')
eth347=	ns.address('saintrichard.eth')
eth348=	ns.address('richardassaf.eth')
eth349=	ns.address('richardfairbank.eth')
eth350=	ns.address('richardish.eth')
eth351=	ns.address('fuckingrichard.eth')
eth352=	ns.address('madisonrichards.eth')
eth353=	ns.address('richardmccrae.eth')
eth354=	ns.address('888richard.eth')
eth355=	ns.address('sirrichardbranson.eth')
eth356=	ns.address('richard3d7.eth')
eth357=	ns.address('trichardson.eth')
eth358=	ns.address('richard669.eth')
eth359=	ns.address('richard002.eth')
eth360=	ns.address('richard-millie.eth')
eth361=	ns.address('lionheartrichard.eth')
eth362=	ns.address('nftrichard.eth')
eth363=	ns.address('cuckoldrichard.eth')
eth364=	ns.address('richard111.eth')
eth365=	ns.address('me-richard.eth')
eth366=	ns.address('richard707.eth')
eth367=	ns.address('richardparayno.eth')
eth368=	ns.address('iamrichard.eth')
eth369=	ns.address('richard23.eth')
eth370=	ns.address('richard899.eth')
eth371=	ns.address('killrichard.eth')
eth372=	ns.address('richard34.eth')
eth373=	ns.address('deniserichards.eth')
eth374=	ns.address('richard-official.eth')
eth375=	ns.address('richardgarfield.eth')
eth376=	ns.address('erectrichard.eth')
eth377=	ns.address('richardrichardrichard.eth')
eth378=	ns.address('richardandballs.eth')
eth379=	ns.address('theodorerichards.eth')
eth380=	ns.address('bestrichard.eth')
eth381=	ns.address('codyrichards.eth')
eth382=	ns.address('richardcoin.eth')
eth383=	ns.address('richardhouse.eth')
eth384=	ns.address('richard24.eth')
eth385=	ns.address('africanrichard.eth')
eth386=	ns.address('richardjr.eth')
eth387=	ns.address('richard🔥.eth')
eth388=	ns.address('richardalderson.eth')
eth389=	ns.address('merichard.eth')
eth390=	ns.address('richardbranson.eth')
eth391=	ns.address('0x👑richard.eth')
eth392=	ns.address('richard45.eth')
eth393=	ns.address('ohrichard.eth')
eth394=	ns.address('richardraizes.eth')
eth395=	ns.address('richard301.eth')
eth396=	ns.address('richard303.eth')
eth397=	ns.address('charichard.eth')
eth398=	ns.address('toprichard.eth')
eth399=	ns.address('run-richard-run.eth')
eth400=	ns.address('richard35.eth')
eth401=	ns.address('richard713.eth')
eth402=	ns.address('richardbonilla.eth')
eth403=	ns.address('richardliu.eth')
eth404=	ns.address('richardwhite.eth')
eth405=	ns.address('richard🍆.eth')
eth406=	ns.address('jsrichards.eth')
eth407=	ns.address('richardbengston.eth')
eth408=	ns.address('richardtom.eth')
eth409=	ns.address('richardispeace.eth')
eth410=	ns.address('1richard.eth')
eth411=	ns.address('richarding.eth')
eth412=	ns.address('richardbirch.eth')
eth413=	ns.address('richardmfer.eth')
eth414=	ns.address('🏴‍☠richard.eth')
eth415=	ns.address('richard44.eth')
eth416=	ns.address('richard0x.eth')
eth417=	ns.address('richardmilledao.eth')
eth418=	ns.address('richardwilson.eth')
eth419=	ns.address('richardadada.eth')
eth420=	ns.address('richardhendricks.eth')
eth421=	ns.address('carlrichards.eth')
eth422=	ns.address('gigarichard.eth')
eth423=	ns.address('minirichard.eth')
eth424=	ns.address('richardlovescrypto.eth')
eth425=	ns.address('richardhubbard.eth')
eth426=	ns.address('richardmille®.eth')
eth427=	ns.address('richardsherman.eth')
eth428=	ns.address('richardjacobs.eth')
eth429=	ns.address('richard123.eth')
eth430=	ns.address('richard369.eth')
eth431=	ns.address('richardbruskoff.eth')
eth432=	ns.address('richardf.eth')
eth433=	ns.address('richardswallet.eth')
eth434=	ns.address('richardovic.eth')
eth435=	ns.address('richardrichardson.eth')
eth436=	ns.address('richard.eth')
eth437=	ns.address('richardthethird.eth')
eth438=	ns.address('vitalikrichardin.eth')
eth439=	ns.address('masterrichard.eth')
eth440=	ns.address('richardrekt.eth')
eth441=	ns.address('jrichard.eth')
eth442=	ns.address('richard50.eth')
eth443=	ns.address('richard109.eth')
eth444=	ns.address('remember-richard.eth')
eth445=	ns.address('big-richard.eth')
eth446=	ns.address('mobyrichard.eth')
eth447=	ns.address('richardcranium.eth')
eth448=	ns.address('londonrichards.eth')
eth449=	ns.address('richardiv.eth')
eth450=	ns.address('richard-mille.eth')
eth451=	ns.address('richardporn.eth')
eth452=	ns.address('richardreserve.eth')
eth453=	ns.address('richardfraser.eth')
eth454=	ns.address('richardc.eth')
eth455=	ns.address('richard1.eth')
eth456=	ns.address('richardsday.eth')
eth457=	ns.address('king-richard.eth')
eth458=	ns.address('markrichardson.eth')
eth459=	ns.address('richardgoodwin.eth')
eth460=	ns.address('richardashe.eth')
eth461=	ns.address('richard86.eth')
eth462=	ns.address('richard3000.eth')
eth463=	ns.address('richardburke.eth')
eth464=	ns.address('mcrichardface.eth')
eth465=	ns.address('arichard.eth')
eth466=	ns.address('fish-richardson.eth')
eth467=	ns.address('richardhole.eth')
eth468=	ns.address('richardandthesorcerersstone.eth')
eth469=	ns.address('richard-the-turd.eth')
eth470=	ns.address('victoriarichardson.eth')
eth471=	ns.address('richardthrasher.eth')
eth472=	ns.address('e-richard.eth')
eth473=	ns.address('lionelrichard.eth')
eth474=	ns.address('kimrichards.eth')
eth475=	ns.address('richardhennessy.eth')
eth476=	ns.address('drrichard.eth')
eth477=	ns.address('richardanthony.eth')
eth478=	ns.address('richardtown.eth')
eth479=	ns.address('karenrichard.eth')
eth480=	ns.address('ensrichard.eth')
eth481=	ns.address('richard112.eth')
eth482=	ns.address('skylarlrichards.eth')
eth483=	ns.address('richard-gere.eth')
eth484=	ns.address('richard858.eth')
eth485=	ns.address('richard444.eth')
eth486=	ns.address('therichrichard.eth')
eth487=	ns.address('richardpilnick.eth')
eth488=	ns.address('richardbeauregard.eth')
eth489=	ns.address('richardbirse.eth')
eth490=	ns.address('richard01.eth')
eth491=	ns.address('u-richard.eth')
eth492=	ns.address('richardkelly.eth')
eth493=	ns.address('richard32.eth')
eth494=	ns.address('drprichard.eth')
eth495=	ns.address('magicrichard.eth')
eth496=	ns.address('ohrichardimsohappyholdme.eth')
eth497=	ns.address('richardism.eth')
eth498=	ns.address('richardxu.eth')
eth499=	ns.address('richard-wallet.eth')
eth500=	ns.address('officialrichard.eth')
eth501=	ns.address('richardkang.eth')
eth502=	ns.address('richard411.eth')
eth503=	ns.address('richardking.eth')
eth504=	ns.address('richardmichaeljordan.eth')
eth505=	ns.address('richardayoade.eth')
eth506=	ns.address('richardnie.eth')
eth507=	ns.address('richard2024.eth')
eth508=	ns.address('richard-club.eth')
eth509=	ns.address('richardmarken.eth')
eth510=	ns.address('richardcan.eth')
eth511=	ns.address('maryrichards.eth')
eth512=	ns.address('rocketrichard.eth')
eth513=	ns.address('richard82.eth')
eth514=	ns.address('richardy.eth')
eth515=	ns.address('originalrichard.eth')
eth516=	ns.address('richardlam.eth')
eth517=	ns.address('fishrichardson.eth')
eth518=	ns.address('richard222.eth')
eth519=	ns.address('the-real-richard.eth')
eth520=	ns.address('richard117.eth')
eth521=	ns.address('nathanielrichard.eth')
eth522=	ns.address('richardchan.eth')
eth523=	ns.address('richardfamily.eth')
eth524=	ns.address('richardcity.eth')
eth525=	ns.address('richard69.eth')
eth526=	ns.address('richardinabox.eth')
eth527=	ns.address('richard305.eth')
eth528=	ns.address('richard900.eth')
eth529=	ns.address('richarddao.eth')
eth530=	ns.address('terrellrichardson.eth')
eth531=	ns.address('richardmille-watches.eth')
eth532=	ns.address('richard13.eth')
eth533=	ns.address('boredrichard.eth')
eth534=	ns.address('richard760.eth')
eth535=	ns.address('richardthe🦁🫀.eth')
eth536=	ns.address('richardolowe.eth')
eth537=	ns.address('richard90.eth')
eth538=	ns.address('timrichardson.eth')
eth539=	ns.address('richardaldana.eth')
eth540=	ns.address('oldrichard.eth')
eth541=	ns.address('snooprichard.eth')
eth542=	ns.address('therichard.eth')
eth543=	ns.address('payrichard.eth')
eth544=	ns.address('richardkirkendall.eth')
eth545=	ns.address('richardholdings.eth')
eth546=	ns.address('richardcock.eth')
eth547=	ns.address('skinnyrichard.eth')
eth548=	ns.address('richardjones.eth')
eth549=	ns.address('richard650.eth')
eth550=	ns.address('richard631.eth')
eth551=	ns.address('rockhardrichard.eth')
eth552=	ns.address('richardbutkus.eth')
eth553=	ns.address('richardingo.eth')
eth554=	ns.address('mikerichard.eth')
eth555=	ns.address('🇺🇸richard.eth')
eth556=	ns.address('richard37.eth')
eth557=	ns.address('richardcantillon.eth')
eth558=	ns.address('thanksrichard.eth')
eth559=	ns.address('whoisrichard.eth')
eth560=	ns.address('richardgreat.eth')
eth561=	ns.address('richardlionheart.eth')
eth562=	ns.address('richardville.eth')
eth563=	ns.address('boredrichardyachtclub.eth')
eth564=	ns.address('👑richard👑.eth')
eth565=	ns.address('richard206.eth')
eth566=	ns.address('drreedrichards.eth')
eth567=	ns.address('richard95.eth')
eth568=	ns.address('inviterichardheartonbankless.eth')
eth569=	ns.address('richard269.eth')
eth570=	ns.address('richardyoo.eth')
eth571=	ns.address('richard313.eth')
eth572=	ns.address('richardians.eth')
eth573=	ns.address('richard48.eth')
eth574=	ns.address('richard789.eth')
eth575=	ns.address('123richard.eth')
eth576=	ns.address('richardjay.eth')
eth577=	ns.address('moonrichard.eth')
eth578=	ns.address('mynameisrichard.eth')
eth579=	ns.address('onlyrichard.eth')
eth580=	ns.address('richardfeynman.eth')
eth581=	ns.address('richard949.eth')
eth582=	ns.address('richard503.eth')
eth583=	ns.address('richardignacio.eth')
eth584=	ns.address('richard666.eth')
eth585=	ns.address('richardashcroft.eth')
eth586=	ns.address('richardsdad.eth')
eth587=	ns.address('richardhenne.eth')
eth588=	ns.address('wearerichard.eth')
eth589=	ns.address('richard59.eth')
eth590=	ns.address('richard006.eth')
eth591=	ns.address('richard😎.eth')
eth592=	ns.address('justrichard.eth')
eth593=	ns.address('amandauprichard.eth')
eth594=	ns.address('richardfoo.eth')
eth595=	ns.address('letsgetricharded.eth')
eth596=	ns.address('eserichard.eth')
eth597=	ns.address('richardheartwin.eth')
eth598=	ns.address('doctorrichard.eth')
eth599=	ns.address('richardspencer.eth')
eth600=	ns.address('richardcraib.eth')
eth601=	ns.address('richardwhatshappening.eth')
eth602=	ns.address('metarichard.eth')
eth603=	ns.address('richardweb3.eth')
eth604=	ns.address('richard213.eth')
eth605=	ns.address('richard260.eth')
eth606=	ns.address('askrichard.eth')
eth607=	ns.address('richardfernandes.eth')
eth608=	ns.address('cryptorichard.eth')
eth609=	ns.address('richardatkins.eth')
eth610=	ns.address('anonrichard.eth')
eth611=	ns.address('richard512.eth')
eth612=	ns.address('richardbeard.eth')
eth613=	ns.address('wtfrichard.eth')
eth614=	ns.address('richardd.eth')
eth615=	ns.address('therichardsons.eth')
eth616=	ns.address('everybodylovesrichard.eth')
eth617=	ns.address('richardsu.eth')
eth618=	ns.address('richardskelhorn.eth')
eth619=	ns.address('richard89.eth')
eth620=	ns.address('richardmusk.eth')
eth621=	ns.address('richard58.eth')
eth622=	ns.address('richard1000.eth')
eth623=	ns.address('richard562.eth')
eth624=	ns.address('richardo.eth')
eth625=	ns.address('richard101.eth')
eth626=	ns.address('anitarichard.eth')
eth627=	ns.address('richard737.eth')
eth628=	ns.address('richardwright.eth')
eth629=	ns.address('simplyrichard.eth')
eth630=	ns.address('richardchoi.eth')
eth631=	ns.address('richardq.eth')
eth632=	ns.address('richardchildressracing.eth')
eth633=	ns.address('richardsun.eth')
eth634=	ns.address('richard114.eth')
eth635=	ns.address('richardoo.eth')
eth636=	ns.address('richard17.eth')
eth637=	ns.address('hellorichard.eth')
eth638=	ns.address('richardsjewelry.eth')
eth639=	ns.address('richard404.eth')
eth640=	ns.address('richard14.eth')
eth641=	ns.address('richardbaxter.eth')
eth642=	ns.address('richardonmymind.eth')
eth643=	ns.address('jeffrichards.eth')
eth644=	ns.address('suckerichard.eth')
eth645=	ns.address('richardswole.eth')
eth646=	ns.address('richardiskevin.eth')
eth647=	ns.address('imrichard.eth')
eth648=	ns.address('richardistan.eth')
eth649=	ns.address('richardyuze.eth')
eth650=	ns.address('chubbyrichard.eth')
eth651=	ns.address('richardhammond.eth')
eth652=	ns.address('🔥richard.eth')
eth653=	ns.address('paparichard.eth')
eth654=	ns.address('notrichard.eth')
eth655=	ns.address('richarditait.eth')
eth656=	ns.address('richard911.eth')
eth657=	ns.address('richard04.eth')
eth658=	ns.address('richardmoon.eth')
eth659=	ns.address('richard069.eth')
eth660=	ns.address('richard60.eth')
eth661=	ns.address('kellyrichardson.eth')
eth662=	ns.address('richardhung.eth')
eth663=	ns.address('richard97.eth')
eth664=	ns.address('richardmeme.eth')
eth665=	ns.address('richardsex.eth')
eth666=	ns.address('richardian.eth')
eth667=	ns.address('letsgorichard.eth')
eth668=	ns.address('richard9999.eth')
eth669=	ns.address('richard1st.eth')
eth670=	ns.address('richardcaring.eth')
eth671=	ns.address('terryrichardson.eth')
eth672=	ns.address('majorrichard.eth')
eth673=	ns.address('lordrichard.eth')
eth674=	ns.address('richardbillyham.eth')
eth675=	ns.address('persianrichard.eth')
eth676=	ns.address('tallrichard.eth')
eth677=	ns.address('fuckrichard.eth')
eth678=	ns.address('richardzhi.eth')
eth679=	ns.address('littlerichard.eth')
eth680=	ns.address('richardr.eth')
eth681=	ns.address('bigdickrichard.eth')
eth682=	ns.address('richardsummer.eth')
eth683=	ns.address('richard93.eth')
eth684=	ns.address('richardtm.eth')
eth685=	ns.address('richardmillie.eth')
eth686=	ns.address('bestrichardever.eth')
eth687=	ns.address('richard151.eth')
eth688=	ns.address('richardese.eth')
eth689=	ns.address('richard1111.eth')
eth690=	ns.address('richardsocher.eth')
eth691=	ns.address('richardsucker.eth')
eth692=	ns.address('richard247.eth')
eth693=	ns.address('richard007.eth')
eth694=	ns.address('smartrichard.eth')
eth695=	ns.address('richard85.eth')
eth696=	ns.address('richardrahcir.eth')
eth697=	ns.address('gregrichardson.eth')
eth698=	ns.address('billrichards.eth')
eth699=	ns.address('richardkimble.eth')
eth700=	ns.address('richardbro.eth')
eth701=	ns.address('richardbirds.eth')
eth702=	ns.address('richardmother.eth')
eth703=	ns.address('bagofrichards.eth')
eth704=	ns.address('mikerichardson.eth')
eth705=	ns.address('asianrichard.eth')
eth706=	ns.address('philrichards.eth')
eth707=	ns.address('😎richard.eth')
eth708=	ns.address('richardng.eth')
eth709=	ns.address('richardwashere.eth')
eth710=	ns.address('richardforpres.eth')
eth711=	ns.address('alpharichard.eth')
eth712=	ns.address('richardkastelein.eth')
eth713=	ns.address('richard52.eth')
eth714=	ns.address('richardmoore.eth')
eth715=	ns.address('richardmilleofficial.eth')
eth716=	ns.address('richardbui.eth')
eth717=	ns.address('richarddoteth.eth')
eth718=	ns.address('richardblack.eth')
eth719=	ns.address('richardsonexcavating.eth')
eth720=	ns.address('richardm.eth')
eth721=	ns.address('richardstroker.eth')
eth722=	ns.address('daddyrichard.eth')
eth723=	ns.address('cherryrichardson.eth')
eth724=	ns.address('jeanrichard.eth')
eth725=	ns.address('myrichard.eth')
eth726=	ns.address('trickyrichard.eth')
eth727=	ns.address('richard212.eth')
eth728=	ns.address('richardw.eth')
eth729=	ns.address('richardphd.eth')
eth730=	ns.address('nathanielrichards.eth')
eth731=	ns.address('richard83.eth')
eth732=	ns.address('harryrichard.eth')
eth733=	ns.address('richardooing.eth')
eth734=	ns.address('misterrichard.eth')
eth735=	ns.address('richardlean.eth')
eth736=	ns.address('colerichards.eth')
eth737=	ns.address('richardheart.eth')
eth738=	ns.address('richardfi.eth')
eth739=	ns.address('famousrichard.eth')
eth740=	ns.address('poorrichardsalmanack.eth')
eth741=	ns.address('suckerrichard.eth')
eth742=	ns.address('pricerichardson.eth')
eth743=	ns.address('richardquesto.eth')
eth744=	ns.address('piraterichard.eth')
eth745=	ns.address('richardisacunt.eth')
eth746=	ns.address('localrichard.eth')
eth747=	ns.address('hyperrichard.eth')
eth748=	ns.address('whatarichard.eth')
eth749=	ns.address('richard96.eth')
eth750=	ns.address('xrichard.eth')
eth751=	ns.address('aderichards.eth')
eth752=	ns.address('thebestrichardever.eth')
eth753=	ns.address('richardchang.eth')
eth754=	ns.address('mutantrichard.eth')
eth755=	ns.address('richardhobbs.eth')
eth756=	ns.address('toddrichards.eth')
eth757=	ns.address('richardolsen.eth')
eth758=	ns.address('nicerichard.eth')
eth759=	ns.address('roxyrichardson.eth')
eth760=	ns.address('brokerichard.eth')
eth761=	ns.address('richard116.eth')
eth762=	ns.address('joshrichards.eth')
eth763=	ns.address('dick-richard.eth')
eth764=	ns.address('richardramos.eth')
eth765=	ns.address('harryrichardson.eth')
eth766=	ns.address('viprichard.eth')
eth767=	ns.address('richardli.eth')
eth768=	ns.address('richardpetty.eth')
eth769=	ns.address('richard22.eth')
eth770=	ns.address('richard106.eth')
eth771=	ns.address('richardsatoshi.eth')
eth772=	ns.address('semirichard.eth')
eth773=	ns.address('richard008.eth')
eth774=	ns.address('tworichards.eth')
eth775=	ns.address('richardus.eth')
eth776=	ns.address('bluechiprichard.eth')
eth777=	ns.address('richard63.eth')
eth778=	ns.address('richard29.eth')
eth779=	ns.address('richardbeer.eth')
eth780=	ns.address('darthrichard.eth')
eth781=	ns.address('richard77.eth')
eth782=	ns.address('toririchard.eth')
eth783=	ns.address('roborichard.eth')
eth784=	ns.address('dashiellrichard.eth')
eth785=	ns.address('richard108.eth')
eth786=	ns.address('presidentrichard.eth')
eth787=	ns.address('richard33.eth')
eth788=	ns.address('richardyong.eth')
eth789=	ns.address('midrichard.eth')
eth790=	ns.address('westleyrichards.eth')
eth791=	ns.address('brichard.eth')
eth792=	ns.address('richard6.eth')
eth793=	ns.address('imnotrichard.eth')
eth794=	ns.address('richardmille.eth')
eth795=	ns.address('richardkettleborough.eth')
eth796=	ns.address('richardurex.eth')
eth797=	ns.address('vivrichards.eth')
eth798=	ns.address('richardbrautigan.eth')
eth799=	ns.address('unclerichard.eth')
eth800=	ns.address('hornyrichard.eth')
eth801=	ns.address('richard317.eth')
eth802=	ns.address('richard314.eth')
eth803=	ns.address('richardii.eth')
eth804=	ns.address('richardthefirst.eth')
eth805=	ns.address('dalerichardson.eth')
eth806=	ns.address('richard000.eth')
eth807=	ns.address('rerichard.eth')
eth808=	ns.address('richard700.eth')
eth809=	ns.address('richard-richard.eth')
eth810=	ns.address('richard711.eth')
eth811=	ns.address('richardnft.eth')
eth812=	ns.address('richard88.eth')
eth813=	ns.address('richarddavies.eth')
eth814=	ns.address('richardz.eth')
eth815=	ns.address('richardthegreat.eth')
eth816=	ns.address('earlyrichard.eth')
eth817=	ns.address('raunchyrichard.eth')
eth818=	ns.address('richard49.eth')
eth819=	ns.address('richardsondackam.eth')
eth820=	ns.address('richard©.eth')
eth821=	ns.address('richardist.eth')
eth822=	ns.address('richarder.eth')
eth823=	ns.address('richardrobson.eth')
eth824=	ns.address('richardi.eth')
eth825=	ns.address('richard69420.eth')
eth826=	ns.address('richard103.eth')
eth827=	ns.address('richardmemes.eth')
eth828=	ns.address('richardsauce.eth')
eth829=	ns.address('richardblankenship.eth')
eth830=	ns.address('richard270.eth')
eth831=	ns.address('richard121.eth')
eth832=	ns.address('arabicrichard.eth')
eth833=	ns.address('richard469.eth')
eth834=	ns.address('richardwilliams.eth')
eth835=	ns.address('richardiam.eth')
eth836=	ns.address('ruggedrichard.eth')
eth837=	ns.address('newrichard.eth')
eth838=	ns.address('richardmiles.eth')
eth839=	ns.address('pepe-richard.eth')
eth840=	ns.address('richard41.eth')
eth841=	ns.address('tylerjrichards.eth')
eth842=	ns.address('richardbrothers.eth')
eth843=	ns.address('stephenrichardson.eth')
eth844=	ns.address('richard61.eth')
eth845=	ns.address('richard21.eth')
eth846=	ns.address('freerichard.eth')
eth847=	ns.address('blockrichard.eth')
eth848=	ns.address('richardjoke.eth')
eth849=	ns.address('richardfather.eth')
eth850=	ns.address('buymorerichard.eth')
eth851=	ns.address('richardrupp.eth')
eth852=	ns.address('limprichard.eth')
eth853=	ns.address('richardvault.eth')
eth854=	ns.address('richardinho.eth')
eth855=	ns.address('richardest.eth')
eth856=	ns.address('richardbay.eth')
eth857=	ns.address('richard619.eth')
eth858=	ns.address('richardthe1st.eth')
eth859=	ns.address('drewrichards.eth')
eth860=	ns.address('richardpill.eth')
eth861=	ns.address('richardpenner.eth')
eth862=	ns.address('richard009.eth')
eth863=	ns.address('shanerichardson.eth')
eth864=	ns.address('richard6969.eth')
eth865=	ns.address('richard57.eth')
eth866=	ns.address('richardmadden.eth')
eth867=	ns.address('richard310.eth')
eth868=	ns.address('okayrichard.eth')
eth869=	ns.address('richardson.eth')
eth870=	ns.address('gnarichard.eth')
eth871=	ns.address('richard4k.eth')
eth872=	ns.address('richard004.eth')
eth873=	ns.address('richardia.eth')
eth874=	ns.address('richard332.eth')
eth875=	ns.address('crazyrichard.eth')
eth876=	ns.address('mattrichards.eth')
eth877=	ns.address('richardjackson.eth')
eth878=	ns.address('richardlong.eth')
eth879=	ns.address('richardroberts.eth')
eth880=	ns.address('harrisonrichard.eth')
eth881=	ns.address('lerichard.eth')
eth882=	ns.address('richarddrahcir.eth')
eth883=	ns.address('richardmercado.eth')
eth884=	ns.address('richardkolecani.eth')
eth885=	ns.address('superrichard.eth')
eth886=	ns.address('richardcore.eth')
eth887=	ns.address('richardgrenell.eth')
eth888=	ns.address('grandparichard.eth')
eth889=	ns.address('bryanjonesrichardson.eth')
eth890=	ns.address('richardmarx.eth')
eth891=	ns.address('richardheartbankless.eth')
eth892=	ns.address('richardmaxi.eth')
eth893=	ns.address('🍆richard.eth')
eth894=	ns.address('richard118.eth')
eth895=	ns.address('richard09.eth')
eth896=	ns.address('letsfuckingrichard.eth')
eth897=	ns.address('whyrichard.eth')
eth898=	ns.address('jordanrichards.eth')
eth899=	ns.address('richardmuirhead.eth')
eth900=	ns.address('saltyrichard.eth')
eth901=	ns.address('richardwang.eth')
eth902=	ns.address('jackrichards.eth')
eth903=	ns.address('richardhatch.eth')
eth904=	ns.address('richardlees.eth')
eth905=	ns.address('restorichard.eth')
eth906=	ns.address('whiskeyrichard.eth')
eth907=	ns.address('richard3rd.eth')
eth908=	ns.address('churchofrichard.eth')
eth909=	ns.address('richardloeser.eth')
eth910=	ns.address('richardthelionheart.eth')
eth911=	ns.address('richard365.eth')
eth912=	ns.address('richardise.eth')
eth913=	ns.address('richardkarnnft.eth')
eth914=	ns.address('richard81.eth')
eth915=	ns.address('richardhaggarty.eth')
eth916=	ns.address('richardsonlending.eth')
eth917=	ns.address('dr-richard.eth')
eth918=	ns.address('richardjunior.eth')
eth919=	ns.address('richardflint.eth')
eth920=	ns.address('richardwho.eth')
eth921=	ns.address('longrichard.eth')
eth922=	ns.address('og-richard.eth')
eth923=	ns.address('richardkain.eth')
eth924=	ns.address('richardxl.eth')
eth925=	ns.address('worldofrichard.eth')
eth926=	ns.address('bryanrichardson.eth')
eth927=	ns.address('bigrichard.eth')
eth928=	ns.address('richardcabral.eth')
eth929=	ns.address('youngrichard.eth')
eth930=	ns.address('pcrichard.eth')
eth931=	ns.address('richard005.eth')
eth932=	ns.address('richardthames.eth')
eth933=	ns.address('richardwad.eth')
eth934=	ns.address('sharearichard.eth')
eth935=	ns.address('richardhughes.eth')
eth936=	ns.address('kingrichard.eth')
eth937=	ns.address('richard507.eth')
eth938=	ns.address('gayrichard.eth')
eth939=	ns.address('richardblumenthal.eth')
eth940=	ns.address('hugerichard.eth')
eth941=	ns.address('richard43.eth')
eth942=	ns.address('richard46.eth')
eth943=	ns.address('richardt.eth')
eth944=	ns.address('richard94.eth')
eth945=	ns.address('richardheartpls.eth')
eth946=	ns.address('iamtherichard.eth')
eth947=	ns.address('richardat.eth')
eth948=	ns.address('byrichard.eth')
eth949=	ns.address('richardhagen.eth')
eth950=	ns.address('richardcorman.eth')
eth951=	ns.address('jakerichardson.eth')
eth952=	ns.address('richardgatz.eth')
eth953=	ns.address('djrichard.eth')
eth954=	ns.address('mcrichard.eth')
eth955=	ns.address('richardlarocque.eth')
eth956=	ns.address('adrianrichardson.eth')
eth957=	ns.address('richard408.eth')
eth958=	ns.address('shadyrichard.eth')
eth959=	ns.address('jrichards.eth')
eth960=	ns.address('rrichard.eth')
eth961=	ns.address('richardnehring.eth')
eth962=	ns.address('richard702.eth')
eth963=	ns.address('poorrichardclub.eth')
eth964=	ns.address('richard987.eth')
eth965=	ns.address('richardgreen.eth')
eth966=	ns.address('richard-branson.eth')
eth967=	ns.address('richardmillewatches.eth')
eth968=	ns.address('vote4richard.eth')
eth969=	ns.address('richardtip.eth')
eth970=	ns.address('richard831.eth')
eth971=	ns.address('stiffrichard.eth')
eth972=	ns.address('richardofficial.eth')
eth973=	ns.address('richardmiller.eth')
eth974=	ns.address('thisisrichard.eth')
eth975=	ns.address('richard-1.eth')
eth976=	ns.address('richard4.eth')
eth977=	ns.address('richards.eth')
eth978=	ns.address('richard714.eth')
eth979=	ns.address('richardzoolander.eth')
eth980=	ns.address('richard18.eth')
eth981=	ns.address('420richard.eth')
eth982=	ns.address('richarddeberry.eth')
eth983=	ns.address('richard39.eth')
eth984=	ns.address('richard98.eth')
eth985=	ns.address('richardkerr.eth')
eth986=	ns.address('richardlease.eth')
eth987=	ns.address('msrichard.eth')
eth988=	ns.address('richrichards.eth')
eth989=	ns.address('punk-richard.eth')
eth990=	ns.address('deadrichard.eth')
eth991=	ns.address('properrichard.eth')
eth992=	ns.address('richardting.eth')
eth993=	ns.address('richardjagger.eth')
eth994=	ns.address('richard38.eth')
eth995=	ns.address('realrichard.eth')
eth996=	ns.address('theonlyrichard.eth')
eth997=	ns.address('richard105.eth')
eth998=	ns.address('richardwu.eth')
eth999=	ns.address('richard122.eth')
eth1000=	ns.address('whosrichard.eth')
eth1001=	ns.address('stankyrichard.eth')
eth1002=	ns.address('blackrichard.eth')
eth1003=	ns.address('richard64.eth')
eth1004=	ns.address('richard74.eth')
eth1005=	ns.address('richard5.eth')
eth1006=	ns.address('richard73.eth')
eth1007=	ns.address('richardschwartz.eth')
eth1008=	ns.address('richard07.eth')
eth1009=	ns.address('richardmdown.eth')
eth1010=	ns.address('richard115.eth')
eth1011=	ns.address('richardverschoor.eth')
eth1012=	ns.address('morphyrichards.eth')
eth1013=	ns.address('heyrichard.eth')
eth1014=	ns.address('2girls1richard.eth')
eth1015=	ns.address('itsrichardswallet.eth')
eth1016=	ns.address('richardtease.eth')
eth1017=	ns.address('richardbrener.eth')
eth1018=	ns.address('richardbutt.eth')
eth1019=	ns.address('richardsandoval.eth')
eth1020=	ns.address('web3richard.eth')
eth1021=	ns.address('richardqiangdongliu.eth')
eth1022=	ns.address('richardhublot.eth')
eth1023=	ns.address('richard541.eth')
eth1024=	ns.address('richard119.eth')
eth1025=	ns.address('richierichardson.eth')
eth1026=	ns.address('richard92.eth')
eth1027=	ns.address('aperichard.eth')
eth1028=	ns.address('darenrichardson.eth')
eth1029=	ns.address('richardk.eth')
eth1030=	ns.address('richardburton.eth')
eth1031=	ns.address('richardtao.eth')
eth1032=	ns.address('richard969.eth')
eth1033=	ns.address('richardfunston.eth')
eth1034=	ns.address('richardherbert.eth')
eth1035=	ns.address('drrichards.eth')
eth1036=	ns.address('docrichard.eth')
eth1037=	ns.address('richarddavis.eth')
eth1038=	ns.address('richardjohnson.eth')
eth1039=	ns.address('i❤richard.eth')
eth1040=	ns.address('richardl.eth')
eth1041=	ns.address('deeprichard.eth')
eth1042=	ns.address('richardv.eth')
eth1043=	ns.address('swinginrichard.eth')
eth1044=	ns.address('richardbollinger.eth')
eth1045=	ns.address('therealrichard.eth')
eth1046=	ns.address('colrichard.eth')
eth1047=	ns.address('richard84.eth')
eth1048=	ns.address('richardens.eth')
eth1049=	ns.address('richard415.eth')
eth1050=	ns.address('richardhead.eth')
eth1051=	ns.address('sansrichard.eth')
eth1052=	ns.address('captrichard.eth')
eth1053=	ns.address('🔥richard🔥.eth')
eth1054=	ns.address('richard100.eth')
eth1055=	ns.address('richardlord.eth')
eth1056=	ns.address('richardboomin.eth')
eth1057=	ns.address('👑richard.eth')
eth1058=	ns.address('captainrichard.eth')
eth1059=	ns.address('runningrichard.eth')
eth1060=	ns.address('richard30.eth')
eth1061=	ns.address('richardpark.eth')
eth1062=	ns.address('richardizard.eth')
eth1063=	ns.address('richardshoeman.eth')
eth1064=	ns.address('suckmyrichard.eth')
eth1065=	ns.address('buddyrichard.eth')
eth1066=	ns.address('richardsdick.eth')
eth1067=	ns.address('mattrichardson.eth')
eth1068=	ns.address('richardlxix.eth')
eth1069=	ns.address('richardstallman.eth')
eth1070=	ns.address('richardental.eth')
eth1071=	ns.address('fatrichard.eth')
eth1072=	ns.address('richardulicky.eth')
eth1073=	ns.address('richard72.eth')
eth1074=	ns.address('reedrichards.eth')
eth1075=	ns.address('richardp.eth')
eth1076=	ns.address('richard54.eth')
eth1077=	ns.address('richardsmith.eth')
eth1078=	ns.address('gmrichard.eth')
eth1079=	ns.address('richard786.eth')
eth1080=	ns.address('richard506.eth')
eth1081=	ns.address('uniquerichard.eth')
eth1082=	ns.address('richard314159265359.eth')
eth1083=	ns.address('fuckerichard.eth')
eth1084=	ns.address('richarded.eth')
eth1085=	ns.address('iloverichard.eth')
eth1086=	ns.address('richard104.eth')
eth1087=	ns.address('richard80.eth')
eth1088=	ns.address('itsrichard.eth')
eth1089=	ns.address('richardwfrank.eth')
eth1090=	ns.address('teamrichard.eth')
eth1091=	ns.address('richard78.eth')
eth1092=	ns.address('richardmilledealer.eth')
eth1093=	ns.address('jesuisrichard.eth')
eth1094=	ns.address('richardzhu.eth')
eth1095=	ns.address('richard300.eth')
eth1096=	ns.address('richardyoung.eth')
eth1097=	ns.address('richardskywalker.eth')
eth1098=	ns.address('richardbachman.eth')
eth1099=	ns.address('richard76.eth')
eth1100=	ns.address('richard0000.eth')
eth1101=	ns.address('richard🇺🇸.eth')
eth1102=	ns.address('richardplepler.eth')
eth1103=	ns.address('richardh.eth')
eth1104=	ns.address('erichard.eth')
eth1105=	ns.address('richardlehane.eth')
eth1106=	ns.address('richardjames.eth')
eth1107=	ns.address('richardmaroun.eth')
eth1108=	ns.address('richard67.eth')
eth1109=	ns.address('richardiii.eth')
eth1110=	ns.address('wrappedrichard.eth')
eth1111=	ns.address('imrichardbiatch.eth')
eth1112=	ns.address('richardunderwood.eth')
eth1113=	ns.address('patrickrichards.eth')
eth1114=	ns.address('richard🧀.eth')
eth1115=	ns.address('richard-anderson.eth')
eth1116=	ns.address('onlyrichards.eth')
eth1117=	ns.address('franklinrichards.eth')
eth1118=	ns.address('richardchen.eth')
eth1119=	ns.address('dontbearichard.eth')
eth1120=	ns.address('8-richard-0.eth')
eth1121=	ns.address('richard425.eth')
eth1122=	ns.address('richardpryor.eth')
eth1123=	ns.address('smolrichard.eth')
eth1124=	ns.address('richard99.eth')
eth1125=	ns.address('richardstreet.eth')
eth1126=	ns.address('richardsoncounty.eth')
eth1127=	ns.address('richard876.eth')
eth1128=	ns.address('richardsanders.eth')
eth1129=	ns.address('richardstarkey.eth')
eth1130=	ns.address('richard00.eth')
eth1131=	ns.address('richardquinn.eth')
eth1132=	ns.address('1strichard.eth')
eth1133=	ns.address('fuckerrichard.eth')
eth1134=	ns.address('richardlittlewood.eth')
eth1135=	ns.address('richard08.eth')
eth1136=	ns.address('ape-richard.eth')
eth1137=	ns.address('richardlin.eth')
eth1138=	ns.address('bigandrichard.eth')
eth1139=	ns.address('jemappellerichard.eth')
eth1140=	ns.address('cgrichard.eth')
eth1141=	ns.address('richardly.eth')
eth1142=	ns.address('richard718.eth')
eth1143=	ns.address('callmerichard.eth')
eth1144=	ns.address('dougrichard.eth')
eth1145=	ns.address('richardsrainwater.eth')
eth1146=	ns.address('chrisrichards.eth')
eth1147=	ns.address('richardscarry.eth')
eth1148=	ns.address('richardpic.eth')
eth1149=	ns.address('richardyuen.eth')
eth1150=	ns.address('richard65.eth')
eth1151=	ns.address('thickrichard.eth')
eth1152=	ns.address('richardofengland.eth')
eth1153=	ns.address('richardofens.eth')
eth1154=	ns.address('richardgarciaofficial.eth')
eth1155=	ns.address('richard53.eth')
eth1156=	ns.address('richard800.eth')
eth1157=	ns.address('rektrichard.eth')
eth1158=	ns.address('richardchild.eth')
eth1159=	ns.address('missrichard.eth')
eth1160=	ns.address('richardigm.eth')
eth1161=	ns.address('richard20.eth')
eth1162=	ns.address('richardvonpepe.eth')
eth1163=	ns.address('yorichard.eth')
eth1164=	ns.address('richardhorrocks.eth')
eth1165=	ns.address('ultrarichard.eth')
eth1166=	ns.address('richard510.eth')
eth1167=	ns.address('richard505.eth')
eth1168=	ns.address('richardserra.eth')
eth1169=	ns.address('richardnfts.eth')
eth1170=	ns.address('richardao.eth')
eth1171=	ns.address('mainrichard.eth')
eth1172=	ns.address('richardkho.eth')
eth1173=	ns.address('richarddreyfuss.eth')
eth1174=	ns.address('richardbandler.eth')
eth1175=	ns.address('pcrichardandson.eth')
eth1176=	ns.address('davidrichards.eth')
eth1177=	ns.address('chiefrichard.eth')
eth1178=	ns.address('cplrichard.eth')
eth1179=	ns.address('richarddeananderson.eth')
eth1180=	ns.address('richardfarleigh.eth')
eth1181=	ns.address('circumcisedrichard.eth')
eth1182=	ns.address('whothefuckisrichard.eth')
eth1183=	ns.address('richardsr.eth')
eth1184=	ns.address('richard3.eth')
eth1185=	ns.address('robotrichard.eth')
eth1186=	ns.address('richard321.eth')
eth1187=	ns.address('ltrichard.eth')
eth1188=	ns.address('richardallen.eth')
eth1189=	ns.address('danielrichard.eth')
eth1190=	ns.address('richard36.eth')
eth1191=	ns.address('richardkclub.eth')
eth1192=	ns.address('richardvan.eth')
eth1193=	ns.address('richardthanyou.eth')
eth1194=	ns.address('richardlearoyd.eth')
eth1195=	ns.address('0xrichardson.eth')
eth1196=	ns.address('richardmillevault.eth')
eth1197=	ns.address('ethrichard.eth')
eth1198=	ns.address('progressiverichard.eth')
eth1199=	ns.address('richardlife.eth')
eth1200=	ns.address('prettyrichard.eth')
eth1201=	ns.address('shutuprichard.eth')
eth1202=	ns.address('uncircumcisedrichard.eth')
eth1203=	ns.address('6richard9.eth')
eth1204=	ns.address('richard42069.eth')
eth1205=	ns.address('anthonyrichardson.eth')
eth1206=	ns.address('moby-richard.eth')
eth1207=	ns.address('bankofrichard.eth')
eth1208=	ns.address('weareallrichard.eth')
eth1209=	ns.address('richardswol.eth')
eth1210=	ns.address('dougrichardco.eth')
eth1211=	ns.address('richardzack.eth')
eth1212=	ns.address('eddierichard.eth')
eth1213=	ns.address('richardbird.eth')
eth1214=	ns.address('richard420.eth')
eth1215=	ns.address('richardfucks.eth')
eth1216=	ns.address('richardwidmark.eth')
eth1217=	ns.address('richard907.eth')
eth1218=	ns.address('richardstrauss.eth')
eth1219=	ns.address('richardpickett.eth')
eth1220=	ns.address('richard05.eth')
eth1221=	ns.address('richardmooney.eth')
eth1222=	ns.address('richard66.eth')
eth1223=	ns.address('jacksonrichardson.eth')
eth1224=	ns.address('richard9.eth')
eth1225=	ns.address('bossrichard.eth')
eth1226=	ns.address('richard10.eth')
eth1227=	ns.address('darkrichard.eth')
eth1228=	ns.address('lord-richard.eth')
eth1229=	ns.address('richardprince.eth')
eth1230=	ns.address('richardheinzl.eth')
eth1231=	ns.address('richardj.eth')
eth1232=	ns.address('richardsondigital.eth')
eth1233=	ns.address('richard79.eth')
eth1234=	ns.address('dotrichard.eth')
eth1235=	ns.address('richardstokoe.eth')
eth1236=	ns.address('richardramirez.eth')
eth1237=	ns.address('richardclub.eth')
eth1238=	ns.address('richardpaulhau.eth')
eth1239=	ns.address('richardzhang.eth')
eth1240=	ns.address('floppyrichard.eth')
eth1241=	ns.address('richard888.eth')
eth1242=	ns.address('mcrichards.eth')
eth1243=	ns.address('richard516.eth')
eth1244=	ns.address('richardbrown.eth')
eth1245=	ns.address('2richard.eth')
eth1246=	ns.address('tinyrichard.eth')
eth1247=	ns.address('richardwong.eth')
eth1248=	ns.address('richard001.eth')
eth1249=	ns.address('richard-bullrun.eth')
eth1250=	ns.address('richardrichards.eth')
eth1251=	ns.address('richardroad.eth')
eth1252=	ns.address('richardheartplusbankless.eth')
eth1253=	ns.address('richarddick.eth')
eth1254=	ns.address('50richard.eth')
eth1255=	ns.address('richardburr.eth')
eth1256=	ns.address('richardcrooks.eth')
eth1257=	ns.address('richard69-420.eth')
eth1258=	ns.address('lilrichard.eth')
eth1259=	ns.address('richyrichard.eth')
eth1260=	ns.address('richardguan.eth')
eth1261=	ns.address('richard360.eth')
# Out:
# 0x43e7D6CF833733b6F7e0c1E4AC5b7FB2A4570807
# 0xe9A4BEC6efAD5ce161b44670af674c2D6daF0793
# 0x7a513A9B13Ca9eC6C2C49d1Bba085BfF0065413f
# 0x650813BA759E0f30b4CDCdBb0FbE5ce58940FEf9
# None
# 0xE5B23976d67d5752F9177a76AB4F5Bc20f4FBa83
# 0x73029536412d32449FB7135469368c65E3DBbE48
# 0x6053904B1643182F235DD8F1A91E851662d93D35
# 0xA4f0C25277Cc1226788AB58B4512551EB1944003
# 0xa2E87Bf4e4EdC28922736887772C351de5554b77
# 0x76B531FcE38Ee72c7CACC882D62502BC865dE3f2
# 0x967b0fc74C321070146Cb7e7B37381292c5ecf8e
# 0xfF6ddb157773197c31a834F6A294c7D0c0abc79F
# 0xc5B424aE1A47b4DE6960D17Fcb26e3f1B464f8A8
# 0xc6Cf0CfC68c445956F50697F734c3E73F9057AD5
# None
# 0xb55050FfF6c64f137C5975aFd296cf8435390AE6
# 0xEfe150ec0d2D4a42AFB5e48566Bf253343Fb70d9
# 0xf8bd714c20D09dC0902932e855d280ED457F9A52
# 0xA214384Fd96D0883A4E4c75036c2863f0F5995f5
# 0x98717560d065DbA4f8C259B9d079818489ad65C2
# 0xd71b74e73B7DEf499B6E2dADd8908EDC1E5a67CC
# None
# 0x7F02E0e4169ce4945462E271e16940264209825B
# ...

# %%
eth501=	ns.address('richardbeauregard.eth')
eth502=	ns.address('richardbirse.eth')
eth503=	ns.address('richard01.eth')
eth504=	ns.address('u-richard.eth')
eth505=	ns.address('richardkelly.eth')
eth506=	ns.address('richard32.eth')
eth507=	ns.address('drprichard.eth')
eth508=	ns.address('magicrichard.eth')
eth509=	ns.address('ohrichardimsohappyholdme.eth')
eth510=	ns.address('richardism.eth')
eth511=	ns.address('richardhearn.dcl.eth')
eth512=	ns.address('test.richard505.eth')
eth513=	ns.address('richardxu.eth')
eth514=	ns.address('richard-wallet.eth')
eth515=	ns.address('officialrichard.eth')
eth516=	ns.address('richardkang.eth')
eth517=	ns.address('richard411.eth')
eth518=	ns.address('richardking.eth')
eth519=	ns.address('richardmichaeljordan.eth')
eth520=	ns.address('richard.golfin.eth')
eth521=	ns.address('richardayoade.eth')
eth522=	ns.address('richardnie.eth')
eth523=	ns.address('richard2024.eth')
eth524=	ns.address('richard-club.eth')
eth525=	ns.address('richardmarken.eth')
eth526=	ns.address('richardcan.eth')
eth527=	ns.address('maryrichards.eth')
eth528=	ns.address('rocketrichard.eth')
eth529=	ns.address('richard82.eth')
eth530=	ns.address('richardy.eth')
eth531=	ns.address('originalrichard.eth')
eth532=	ns.address('richardlam.eth')
eth533=	ns.address('fishrichardson.eth')
eth534=	ns.address('richard222.eth')
eth535=	ns.address('the-real-richard.eth')
eth536=	ns.address('richard117.eth')
eth537=	ns.address('nathanielrichard.eth')
eth538=	ns.address('richardchan.eth')
eth539=	ns.address('richardfamily.eth')
eth540=	ns.address('richardcity.eth')
eth541=	ns.address('richard69.eth')
eth542=	ns.address('richardinabox.eth')
eth543=	ns.address('richard305.eth')
eth544=	ns.address('richard900.eth')
eth545=	ns.address('richarddao.eth')
eth546=	ns.address('richardheart.pumpamentals.eth')
eth547=	ns.address('terrellrichardson.eth')
eth548=	ns.address('richardmille-watches.eth')
eth549=	ns.address('richard13.eth')
eth550=	ns.address('boredrichard.eth')
eth551=	ns.address('richard760.eth')
eth552=	ns.address('richardthe🦁🫀.eth')
eth553=	ns.address('richardolowe.eth')
eth554=	ns.address('richard90.eth')
eth555=	ns.address('timrichardson.eth')
eth556=	ns.address('richardaldana.eth')
eth557=	ns.address('oldrichard.eth')
eth558=	ns.address('snooprichard.eth')
eth559=	ns.address('therichard.eth')
eth560=	ns.address('payrichard.eth')
eth561=	ns.address('richardkirkendall.eth')
eth562=	ns.address('richardholdings.eth')
eth563=	ns.address('richardcock.eth')
eth564=	ns.address('skinnyrichard.eth')
eth565=	ns.address('richardjones.eth')
eth566=	ns.address('richard650.eth')
eth567=	ns.address('richard631.eth')
eth568=	ns.address('rockhardrichard.eth')
eth569=	ns.address('richardbutkus.eth')
eth570=	ns.address('richard.authereum.eth')
eth571=	ns.address('richardingo.eth')
eth572=	ns.address('mikerichard.eth')
eth573=	ns.address('🇺🇸richard.eth')
eth574=	ns.address('richard37.eth')
eth575=	ns.address('richardcantillon.eth')
eth576=	ns.address('thanksrichard.eth')
eth577=	ns.address('whoisrichard.eth')
eth578=	ns.address('richardgreat.eth')
eth579=	ns.address('richardlionheart.eth')
eth580=	ns.address('richardville.eth')
eth581=	ns.address('boredrichardyachtclub.eth')
eth582=	ns.address('👑richard👑.eth')
eth583=	ns.address('richard206.eth')
eth584=	ns.address('drreedrichards.eth')
eth585=	ns.address('richard95.eth')
eth586=	ns.address('inviterichardheartonbankless.eth')
eth587=	ns.address('richard269.eth')
eth588=	ns.address('richardyoo.eth')
eth589=	ns.address('richard313.eth')
eth590=	ns.address('richardians.eth')
eth591=	ns.address('richard48.eth')
eth592=	ns.address('richard789.eth')
eth593=	ns.address('123richard.eth')
eth594=	ns.address('richardjay.eth')
eth595=	ns.address('moonrichard.eth')
eth596=	ns.address('richardcraib.auth.eth')
eth597=	ns.address('mynameisrichard.eth')
eth598=	ns.address('onlyrichard.eth')
eth599=	ns.address('richardfeynman.eth')
eth600=	ns.address('richard949.eth')
eth601=	ns.address('richard503.eth')
eth602=	ns.address('richardignacio.eth')
eth603=	ns.address('richard666.eth')
eth604=	ns.address('richardashcroft.eth')
eth605=	ns.address('richardsdad.eth')
eth606=	ns.address('richardhenne.eth')
eth607=	ns.address('wearerichard.eth')
eth608=	ns.address('richard59.eth')
eth609=	ns.address('richard006.eth')
eth610=	ns.address('richard😎.eth')
eth611=	ns.address('justrichard.eth')
eth612=	ns.address('amandauprichard.eth')
eth613=	ns.address('richardfoo.eth')
eth614=	ns.address('letsgetricharded.eth')
eth615=	ns.address('eserichard.eth')
eth616=	ns.address('richardheartwin.eth')
eth617=	ns.address('doctorrichard.eth')
eth618=	ns.address('richardspencer.eth')
eth619=	ns.address('richardcraib.eth')
eth620=	ns.address('richardwhatshappening.eth')
eth621=	ns.address('metarichard.eth')
eth622=	ns.address('richardweb3.eth')
eth623=	ns.address('richard213.eth')
eth624=	ns.address('richard260.eth')
eth625=	ns.address('askrichard.eth')
eth626=	ns.address('richardfernandes.eth')
eth627=	ns.address('cryptorichard.eth')
eth628=	ns.address('richardatkins.eth')
eth629=	ns.address('anonrichard.eth')
eth630=	ns.address('richard512.eth')
eth631=	ns.address('richardbeard.eth')
eth632=	ns.address('richardliu.thisisme.eth')
eth633=	ns.address('wtfrichard.eth')
eth634=	ns.address('richardd.eth')
eth635=	ns.address('therichardsons.eth')
eth636=	ns.address('everybodylovesrichard.eth')
eth637=	ns.address('richardsu.eth')
eth638=	ns.address('richardskelhorn.eth')
eth639=	ns.address('richard89.eth')
eth640=	ns.address('richardmusk.eth')
eth641=	ns.address('richard58.eth')
eth642=	ns.address('richard1000.eth')
eth643=	ns.address('richard562.eth')
eth644=	ns.address('richardo.eth')
eth645=	ns.address('richard101.eth')
eth646=	ns.address('anitarichard.eth')
eth647=	ns.address('richard737.eth')
eth648=	ns.address('richardwright.eth')
eth649=	ns.address('simplyrichard.eth')
eth650=	ns.address('richardchoi.eth')
eth651=	ns.address('richardq.eth')
eth652=	ns.address('richardchildressracing.eth')
eth653=	ns.address('richardsun.eth')
eth654=	ns.address('richard114.eth')
eth655=	ns.address('richardoo.eth')
eth656=	ns.address('richard17.eth')
eth657=	ns.address('hellorichard.eth')
eth658=	ns.address('richard.loopring.eth')
eth659=	ns.address('richardsjewelry.eth')
eth660=	ns.address('richard404.eth')
eth661=	ns.address('richard14.eth')
eth662=	ns.address('richardbaxter.eth')
eth663=	ns.address('richardonmymind.eth')
eth664=	ns.address('jeffrichards.eth')
eth665=	ns.address('suckerichard.eth')
eth666=	ns.address('richardswole.eth')
eth667=	ns.address('richardiskevin.eth')
eth668=	ns.address('imrichard.eth')
eth669=	ns.address('richardistan.eth')
eth670=	ns.address('skel.richardskelhorn.eth')
eth671=	ns.address('richardyuze.eth')
eth672=	ns.address('chubbyrichard.eth')
eth673=	ns.address('richardhammond.eth')
eth674=	ns.address('🔥richard.eth')
eth675=	ns.address('paparichard.eth')
eth676=	ns.address('notrichard.eth')
eth677=	ns.address('richarditait.eth')
eth678=	ns.address('richard911.eth')
eth679=	ns.address('richard04.eth')
eth680=	ns.address('richardmoon.eth')
eth681=	ns.address('richard069.eth')
eth682=	ns.address('richard60.eth')
eth683=	ns.address('kellyrichardson.eth')
eth684=	ns.address('richardhung.eth')
eth685=	ns.address('richard97.eth')
eth686=	ns.address('richardmeme.eth')
eth687=	ns.address('richardsex.eth')
eth688=	ns.address('richardian.eth')
eth689=	ns.address('letsgorichard.eth')
eth690=	ns.address('richard9999.eth')
eth691=	ns.address('richard1st.eth')
eth692=	ns.address('richardcaring.eth')
eth693=	ns.address('terryrichardson.eth')
eth694=	ns.address('majorrichard.eth')
eth695=	ns.address('lordrichard.eth')
eth696=	ns.address('richardbillyham.eth')
eth697=	ns.address('persianrichard.eth')
eth698=	ns.address('tallrichard.eth')
eth699=	ns.address('fuckrichard.eth')
eth700=	ns.address('richardzhi.eth')
eth701=	ns.address('littlerichard.eth')
eth702=	ns.address('richardr.eth')
eth703=	ns.address('bigdickrichard.eth')
eth704=	ns.address('richardsummer.eth')
eth705=	ns.address('richard93.eth')
eth706=	ns.address('richardtm.eth')
eth707=	ns.address('richardmillie.eth')
eth708=	ns.address('bestrichardever.eth')
eth709=	ns.address('richard151.eth')
eth710=	ns.address('richardese.eth')
eth711=	ns.address('richard1111.eth')
eth712=	ns.address('richardsocher.eth')
eth713=	ns.address('richardsucker.eth')
eth714=	ns.address('richard247.eth')
eth715=	ns.address('richard007.eth')
eth716=	ns.address('smartrichard.eth')
eth717=	ns.address('richard85.eth')
eth718=	ns.address('richardrahcir.eth')
eth719=	ns.address('gregrichardson.eth')
eth720=	ns.address('billrichards.eth')
eth721=	ns.address('richardkimble.eth')
eth722=	ns.address('richardbro.eth')
eth723=	ns.address('richardbirds.eth')
eth724=	ns.address('richardmother.eth')
eth725=	ns.address('bagofrichards.eth')
eth726=	ns.address('mikerichardson.eth')
eth727=	ns.address('asianrichard.eth')
eth728=	ns.address('philrichards.eth')
eth729=	ns.address('😎richard.eth')
eth730=	ns.address('richardng.eth')
eth731=	ns.address('richardwashere.eth')
eth732=	ns.address('richardforpres.eth')
eth733=	ns.address('alpharichard.eth')
eth734=	ns.address('richardkastelein.eth')
eth735=	ns.address('richard52.eth')
eth736=	ns.address('richardmoore.eth')
eth737=	ns.address('richardmilleofficial.eth')
eth738=	ns.address('richardbui.eth')
eth739=	ns.address('richarddoteth.eth')
eth740=	ns.address('richardblack.eth')
eth741=	ns.address('richardsonexcavating.eth')
eth742=	ns.address('richardm.eth')
eth743=	ns.address('richardstroker.eth')
eth744=	ns.address('daddyrichard.eth')
eth745=	ns.address('cherryrichardson.eth')
eth746=	ns.address('jeanrichard.eth')
eth747=	ns.address('myrichard.eth')
eth748=	ns.address('trickyrichard.eth')
eth749=	ns.address('richard212.eth')
eth750=	ns.address('richardw.eth')
eth751=	ns.address('richardphd.eth')
eth752=	ns.address('nathanielrichards.eth')
eth753=	ns.address('richard83.eth')
eth754=	ns.address('harryrichard.eth')
eth755=	ns.address('richardooing.eth')
eth756=	ns.address('misterrichard.eth')
eth757=	ns.address('richardlean.eth')
eth758=	ns.address('colerichards.eth')
eth759=	ns.address('richardheart.eth')
eth760=	ns.address('richardfi.eth')
eth761=	ns.address('famousrichard.eth')
eth762=	ns.address('poorrichardsalmanack.eth')
eth763=	ns.address('suckerrichard.eth')
eth764=	ns.address('pricerichardson.eth')
eth765=	ns.address('richardquesto.eth')
eth766=	ns.address('piraterichard.eth')
eth767=	ns.address('richardisacunt.eth')
eth768=	ns.address('localrichard.eth')
eth769=	ns.address('hyperrichard.eth')
eth770=	ns.address('whatarichard.eth')
eth771=	ns.address('richard96.eth')
eth772=	ns.address('xrichard.eth')
eth773=	ns.address('aderichards.eth')
eth774=	ns.address('thebestrichardever.eth')
eth775=	ns.address('richardchang.eth')
eth776=	ns.address('mutantrichard.eth')
eth777=	ns.address('richardhobbs.eth')
eth778=	ns.address('toddrichards.eth')
eth779=	ns.address('richardolsen.eth')
eth780=	ns.address('nicerichard.eth')
eth781=	ns.address('roxyrichardson.eth')
eth782=	ns.address('brokerichard.eth')
eth783=	ns.address('richard116.eth')
eth784=	ns.address('joshrichards.eth')
eth785=	ns.address('dick-richard.eth')
eth786=	ns.address('richardramos.eth')
eth787=	ns.address('harryrichardson.eth')
eth788=	ns.address('viprichard.eth')
eth789=	ns.address('richardli.eth')
eth790=	ns.address('richardpetty.eth')
eth791=	ns.address('richard22.eth')
eth792=	ns.address('richard106.eth')
eth793=	ns.address('richardsatoshi.eth')
eth794=	ns.address('semirichard.eth')
eth795=	ns.address('richard008.eth')
eth796=	ns.address('tworichards.eth')
eth797=	ns.address('richardus.eth')
eth798=	ns.address('bluechiprichard.eth')
eth799=	ns.address('richard63.eth')
eth800=	ns.address('richard29.eth')
eth801=	ns.address('richardbeer.eth')
eth802=	ns.address('darthrichard.eth')
eth803=	ns.address('richard77.eth')
eth804=	ns.address('toririchard.eth')
eth805=	ns.address('roborichard.eth')
eth806=	ns.address('dashiellrichard.eth')
eth807=	ns.address('samrichards.etherbase.eth')
eth808=	ns.address('richard108.eth')
eth809=	ns.address('richardheart.dcl.eth')
eth810=	ns.address('presidentrichard.eth')
eth811=	ns.address('richard33.eth')
eth812=	ns.address('richardyong.eth')
eth813=	ns.address('midrichard.eth')
eth814=	ns.address('westleyrichards.eth')
eth815=	ns.address('brichard.eth')
eth816=	ns.address('richard6.eth')
eth817=	ns.address('imnotrichard.eth')
eth818=	ns.address('richardmille.eth')
eth819=	ns.address('richardkettleborough.eth')
eth820=	ns.address('richardurex.eth')
eth821=	ns.address('vivrichards.eth')
eth822=	ns.address('richardbrautigan.eth')
eth823=	ns.address('unclerichard.eth')
eth824=	ns.address('hornyrichard.eth')
eth825=	ns.address('richard317.eth')
eth826=	ns.address('richard314.eth')
eth827=	ns.address('richardii.eth')
eth828=	ns.address('richardthefirst.eth')
eth829=	ns.address('dalerichardson.eth')
eth830=	ns.address('richard000.eth')
eth831=	ns.address('rerichard.eth')
eth832=	ns.address('richard700.eth')
eth833=	ns.address('richard-richard.eth')
eth834=	ns.address('richard711.eth')
eth835=	ns.address('richardnft.eth')
eth836=	ns.address('richard88.eth')
eth837=	ns.address('richarddavies.eth')
eth838=	ns.address('richardz.eth')
eth839=	ns.address('richardthegreat.eth')
eth840=	ns.address('earlyrichard.eth')
eth841=	ns.address('raunchyrichard.eth')
eth842=	ns.address('richard49.eth')
eth843=	ns.address('richardsondackam.eth')
eth844=	ns.address('richard©.eth')
eth845=	ns.address('richardist.eth')
eth846=	ns.address('richarder.eth')
eth847=	ns.address('richardrobson.eth')
eth848=	ns.address('richardi.eth')
eth849=	ns.address('richard69420.eth')
eth850=	ns.address('richard103.eth')
eth851=	ns.address('richardmemes.eth')
eth852=	ns.address('richardsauce.eth')
eth853=	ns.address('richardblankenship.eth')
eth854=	ns.address('richard270.eth')
eth855=	ns.address('richard121.eth')
eth856=	ns.address('arabicrichard.eth')
eth857=	ns.address('richard469.eth')
eth858=	ns.address('richardwilliams.eth')
eth859=	ns.address('richardiam.eth')
eth860=	ns.address('ruggedrichard.eth')
eth861=	ns.address('newrichard.eth')
eth862=	ns.address('richardmiles.eth')
eth863=	ns.address('pepe-richard.eth')
eth864=	ns.address('richard41.eth')
eth865=	ns.address('tylerjrichards.eth')
eth866=	ns.address('richardbrothers.eth')
eth867=	ns.address('stephenrichardson.eth')
eth868=	ns.address('richard61.eth')
eth869=	ns.address('richard21.eth')
eth870=	ns.address('freerichard.eth')
eth871=	ns.address('keithrichards.dcl.eth')
eth872=	ns.address('blockrichard.eth')
eth873=	ns.address('richardjoke.eth')
eth874=	ns.address('richardfather.eth')
eth875=	ns.address('buymorerichard.eth')
eth876=	ns.address('richardrupp.eth')
eth877=	ns.address('richardsanchez.dcl.eth')
eth878=	ns.address('limprichard.eth')
eth879=	ns.address('richardvault.eth')
eth880=	ns.address('richardinho.eth')
eth881=	ns.address('richardest.eth')
eth882=	ns.address('richardbay.eth')
eth883=	ns.address('richard619.eth')
eth884=	ns.address('richardthe1st.eth')
eth885=	ns.address('drewrichards.eth')
eth886=	ns.address('richardpill.eth')
eth887=	ns.address('richardpenner.eth')
eth888=	ns.address('richard009.eth')
eth889=	ns.address('shanerichardson.eth')
eth890=	ns.address('richard6969.eth')
eth891=	ns.address('richard57.eth')
eth892=	ns.address('richardmadden.eth')
eth893=	ns.address('richard310.eth')
eth894=	ns.address('okayrichard.eth')
eth895=	ns.address('richardson.eth')
eth896=	ns.address('gnarichard.eth')
eth897=	ns.address('richard4k.eth')
eth898=	ns.address('richard004.eth')
eth899=	ns.address('richardia.eth')
eth900=	ns.address('richard332.eth')
eth901=	ns.address('crazyrichard.eth')
eth902=	ns.address('mattrichards.eth')
eth903=	ns.address('richardjackson.eth')
eth904=	ns.address('richardlong.eth')
eth905=	ns.address('richardroberts.eth')
eth906=	ns.address('harrisonrichard.eth')
eth907=	ns.address('lerichard.eth')
eth908=	ns.address('richarddrahcir.eth')
eth909=	ns.address('richardmercado.eth')
eth910=	ns.address('richardkolecani.eth')
eth911=	ns.address('superrichard.eth')
eth912=	ns.address('richardcore.eth')
eth913=	ns.address('richardgrenell.eth')
eth914=	ns.address('grandparichard.eth')
eth915=	ns.address('bryanjonesrichardson.eth')
eth916=	ns.address('richardmarx.eth')
eth917=	ns.address('richardheartbankless.eth')
eth918=	ns.address('richardmaxi.eth')
eth919=	ns.address('🍆richard.eth')
eth920=	ns.address('richard118.eth')
eth921=	ns.address('richard09.eth')
eth922=	ns.address('letsfuckingrichard.eth')
eth923=	ns.address('whyrichard.eth')
eth924=	ns.address('jordanrichards.eth')
eth925=	ns.address('richardmuirhead.eth')
eth926=	ns.address('saltyrichard.eth')
eth927=	ns.address('richardwang.eth')
eth928=	ns.address('jackrichards.eth')
eth929=	ns.address('cryptorichard.pillar.eth')
eth930=	ns.address('richard.norcal.eth')
eth931=	ns.address('richardhatch.eth')
eth932=	ns.address('richardlees.eth')
eth933=	ns.address('restorichard.eth')
eth934=	ns.address('whiskeyrichard.eth')
eth935=	ns.address('richard3rd.eth')
eth936=	ns.address('churchofrichard.eth')
eth937=	ns.address('richardxlin.gitcoin.eth')
eth938=	ns.address('richardloeser.eth')
eth939=	ns.address('richardthelionheart.eth')
eth940=	ns.address('richard365.eth')
eth941=	ns.address('richardise.eth')
eth942=	ns.address('richardkarnnft.eth')
eth943=	ns.address('richard81.eth')
eth944=	ns.address('richardhaggarty.eth')
eth945=	ns.address('richardsonlending.eth')
eth946=	ns.address('dr-richard.eth')
eth947=	ns.address('richardjunior.eth')
eth948=	ns.address('richardflint.eth')
eth949=	ns.address('richardwho.eth')
eth950=	ns.address('r.richardmutt.eth')
eth951=	ns.address('longrichard.eth')
eth952=	ns.address('og-richard.eth')
eth953=	ns.address('richardkain.eth')
eth954=	ns.address('richardxl.eth')
eth955=	ns.address('worldofrichard.eth')
eth956=	ns.address('bryanrichardson.eth')
eth957=	ns.address('bigrichard.eth')
eth958=	ns.address('richardcabral.eth')
eth959=	ns.address('youngrichard.eth')
eth960=	ns.address('pcrichard.eth')
eth961=	ns.address('richard005.eth')
eth962=	ns.address('richardthames.eth')
eth963=	ns.address('richardwad.eth')
eth964=	ns.address('sharearichard.eth')
eth965=	ns.address('richardhughes.eth')
eth966=	ns.address('kingrichard.eth')
eth967=	ns.address('richard507.eth')
eth968=	ns.address('gayrichard.eth')
eth969=	ns.address('richardblumenthal.eth')
eth970=	ns.address('hugerichard.eth')
eth971=	ns.address('richard43.eth')
eth972=	ns.address('richard46.eth')
eth973=	ns.address('richardt.eth')
eth974=	ns.address('richard94.eth')
eth975=	ns.address('richardheartpls.eth')
eth976=	ns.address('iamtherichard.eth')
eth977=	ns.address('richardat.eth')
eth978=	ns.address('byrichard.eth')
eth979=	ns.address('richardhagen.eth')
eth980=	ns.address('richardcorman.eth')
eth981=	ns.address('jakerichardson.eth')
eth982=	ns.address('richardgatz.eth')
eth983=	ns.address('djrichard.eth')
eth984=	ns.address('mcrichard.eth')
eth985=	ns.address('richardlarocque.eth')
eth986=	ns.address('adrianrichardson.eth')
eth987=	ns.address('richard408.eth')
eth988=	ns.address('shadyrichard.eth')
eth989=	ns.address('jrichards.eth')
eth990=	ns.address('rrichard.eth')
eth991=	ns.address('richardnehring.eth')
eth992=	ns.address('richard702.eth')
eth993=	ns.address('poorrichardclub.eth')
eth994=	ns.address('richard987.eth')
eth995=	ns.address('richardgreen.eth')
eth996=	ns.address('richard-branson.eth')
eth997=	ns.address('richardmillewatches.eth')
eth998=	ns.address('vote4richard.eth')
eth999=	ns.address('richardtip.eth')
eth1000= ns.address('richard831.eth')

print(eth501)
print(eth502)
print(eth503)
print(eth504)
print(eth505)
print(eth506)
print(eth507)
print(eth508)
print(eth509)
print(eth510)
print(eth511)
print(eth512)
print(eth513)
print(eth514)
print(eth515)
print(eth516)
print(eth517)
print(eth518)
print(eth519)
print(eth520)
print(eth521)
print(eth522)
print(eth523)
print(eth524)
print(eth525)
print(eth526)
print(eth527)
print(eth528)
print(eth529)
print(eth530)
print(eth531)
print(eth532)
print(eth533)
print(eth534)
print(eth535)
print(eth536)
print(eth537)
print(eth538)
print(eth539)
print(eth540)
print(eth541)
print(eth542)
print(eth543)
print(eth544)
print(eth545)
print(eth546)
print(eth547)
print(eth548)
print(eth549)
print(eth550)
print(eth551)
print(eth552)
print(eth553)
print(eth554)
print(eth555)
print(eth556)
print(eth557)
print(eth558)
print(eth559)
print(eth560)
print(eth561)
print(eth562)
print(eth563)
print(eth564)
print(eth565)
print(eth566)
print(eth567)
print(eth568)
print(eth569)
print(eth570)
print(eth571)
print(eth572)
print(eth573)
print(eth574)
print(eth575)
print(eth576)
print(eth577)
print(eth578)
print(eth579)
print(eth580)
print(eth581)
print(eth582)
print(eth583)
print(eth584)
print(eth585)
print(eth586)
print(eth587)
print(eth588)
print(eth589)
print(eth590)
print(eth591)
print(eth592)
print(eth593)
print(eth594)
print(eth595)
print(eth596)
print(eth597)
print(eth598)
print(eth599)
print(eth600)
print(eth601)
print(eth602)
print(eth603)
print(eth604)
print(eth605)
print(eth606)
print(eth607)
print(eth608)
print(eth609)
print(eth610)
print(eth611)
print(eth612)
print(eth613)
print(eth614)
print(eth615)
print(eth616)
print(eth617)
print(eth618)
print(eth619)
print(eth620)
print(eth621)
print(eth622)
print(eth623)
print(eth624)
print(eth625)
print(eth626)
print(eth627)
print(eth628)
print(eth629)
print(eth630)
print(eth631)
print(eth632)
print(eth633)
print(eth634)
print(eth635)
print(eth636)
print(eth637)
print(eth638)
print(eth639)
print(eth640)
print(eth641)
print(eth642)
print(eth643)
print(eth644)
print(eth645)
print(eth646)
print(eth647)
print(eth648)
print(eth649)
print(eth650)
print(eth651)
print(eth652)
print(eth653)
print(eth654)
print(eth655)
print(eth656)
print(eth657)
print(eth658)
print(eth659)
print(eth660)
print(eth661)
print(eth662)
print(eth663)
print(eth664)
print(eth665)
print(eth666)
print(eth667)
print(eth668)
print(eth669)
print(eth670)
print(eth671)
print(eth672)
print(eth673)
print(eth674)
print(eth675)
print(eth676)
print(eth677)
print(eth678)
print(eth679)
print(eth680)
print(eth681)
print(eth682)
print(eth683)
print(eth684)
print(eth685)
print(eth686)
print(eth687)
print(eth688)
print(eth689)
print(eth690)
print(eth691)
print(eth692)
print(eth693)
print(eth694)
print(eth695)
print(eth696)
print(eth697)
print(eth698)
print(eth699)
print(eth700)
print(eth701)
print(eth702)
print(eth703)
print(eth704)
print(eth705)
print(eth706)
print(eth707)
print(eth708)
print(eth709)
print(eth710)
print(eth711)
print(eth712)
print(eth713)
print(eth714)
print(eth715)
print(eth716)
print(eth717)
print(eth718)
print(eth719)
print(eth720)
print(eth721)
print(eth722)
print(eth723)
print(eth724)
print(eth725)
print(eth726)
print(eth727)
print(eth728)
print(eth729)
print(eth730)
print(eth731)
print(eth732)
print(eth733)
print(eth734)
print(eth735)
print(eth736)
print(eth737)
print(eth738)
print(eth739)
print(eth740)
print(eth741)
print(eth742)
print(eth743)
print(eth744)
print(eth745)
print(eth746)
print(eth747)
print(eth748)
print(eth749)
print(eth750)
print(eth751)
print(eth752)
print(eth753)
print(eth754)
print(eth755)
print(eth756)
print(eth757)
print(eth758)
print(eth759)
print(eth760)
print(eth761)
print(eth762)
print(eth763)
print(eth764)
print(eth765)
print(eth766)
print(eth767)
print(eth768)
print(eth769)
print(eth770)
print(eth771)
print(eth772)
print(eth773)
print(eth774)
print(eth775)
print(eth776)
print(eth777)
print(eth778)
print(eth779)
print(eth780)
print(eth781)
print(eth782)
print(eth783)
print(eth784)
print(eth785)
print(eth786)
print(eth787)
print(eth788)
print(eth789)
print(eth790)
print(eth791)
print(eth792)
print(eth793)
print(eth794)
print(eth795)
print(eth796)
print(eth797)
print(eth798)
print(eth799)
print(eth800)
print(eth801)
print(eth802)
print(eth803)
print(eth804)
print(eth805)
print(eth806)
print(eth807)
print(eth808)
print(eth809)
print(eth810)
print(eth811)
print(eth812)
print(eth813)
print(eth814)
print(eth815)
print(eth816)
print(eth817)
print(eth818)
print(eth819)
print(eth820)
print(eth821)
print(eth822)
print(eth823)
print(eth824)
print(eth825)
print(eth826)
print(eth827)
print(eth828)
print(eth829)
print(eth830)
print(eth831)
print(eth832)
print(eth833)
print(eth834)
print(eth835)
print(eth836)
print(eth837)
print(eth838)
print(eth839)
print(eth840)
print(eth841)
print(eth842)
print(eth843)
print(eth844)
print(eth845)
print(eth846)
print(eth847)
print(eth848)
print(eth849)
print(eth850)
print(eth851)
print(eth852)
print(eth853)
print(eth854)
print(eth855)
print(eth856)
print(eth857)
print(eth858)
print(eth859)
print(eth860)
print(eth861)
print(eth862)
print(eth863)
print(eth864)
print(eth865)
print(eth866)
print(eth867)
print(eth868)
print(eth869)
print(eth870)
print(eth871)
print(eth872)
print(eth873)
print(eth874)
print(eth875)
print(eth876)
print(eth877)
print(eth878)
print(eth879)
print(eth880)
print(eth881)
print(eth882)
print(eth883)
print(eth884)
print(eth885)
print(eth886)
print(eth887)
print(eth888)
print(eth889)
print(eth890)
print(eth891)
print(eth892)
print(eth893)
print(eth894)
print(eth895)
print(eth896)
print(eth897)
print(eth898)
print(eth899)
print(eth900)
print(eth901)
print(eth902)
print(eth903)
print(eth904)
print(eth905)
print(eth906)
print(eth907)
print(eth908)
print(eth909)
print(eth910)
print(eth911)
print(eth912)
print(eth913)
print(eth914)
print(eth915)
print(eth916)
print(eth917)
print(eth918)
print(eth919)
print(eth920)
print(eth921)
print(eth922)
print(eth923)
print(eth924)
print(eth925)
print(eth926)
print(eth927)
print(eth928)
print(eth929)
print(eth930)
print(eth931)
print(eth932)
print(eth933)
print(eth934)
print(eth935)
print(eth936)
print(eth937)
print(eth938)
print(eth939)
print(eth940)
print(eth941)
print(eth942)
print(eth943)
print(eth944)
print(eth945)
print(eth946)
print(eth947)
print(eth948)
print(eth949)
print(eth950)
print(eth951)
print(eth952)
print(eth953)
print(eth954)
print(eth955)
print(eth956)
print(eth957)
print(eth958)
print(eth959)
print(eth960)
print(eth961)
print(eth962)
print(eth963)
print(eth964)
print(eth965)
print(eth966)
print(eth967)
print(eth968)
print(eth969)
print(eth970)
print(eth971)
print(eth972)
print(eth973)
print(eth974)
print(eth975)
print(eth976)
print(eth977)
print(eth978)
print(eth979)
print(eth980)
print(eth981)
print(eth982)
print(eth983)
print(eth984)
print(eth985)
print(eth986)
print(eth987)
print(eth988)
print(eth989)
print(eth990)
print(eth991)
print(eth992)
print(eth993)
print(eth994)
print(eth995)
print(eth996)
print(eth997)
print(eth998)
print(eth999)
print(eth1000)
print(eth1001)
print(eth1002)
print(eth1003)
print(eth1004)
print(eth1005)
print(eth1006)
print(eth1007)
print(eth1008)
print(eth1009)
print(eth1010)
print(eth1011)
print(eth1012)
print(eth1013)
print(eth1014)
print(eth1015)
print(eth1016)
print(eth1017)
print(eth1018)
print(eth1019)
print(eth1020)
print(eth1021)
print(eth1022)
print(eth1023)
print(eth1024)
print(eth1025)
print(eth1026)
print(eth1027)
print(eth1028)
print(eth1029)
print(eth1030)
print(eth1031)
print(eth1032)
print(eth1033)
print(eth1034)
print(eth1035)
print(eth1036)
print(eth1037)
print(eth1038)
print(eth1039)
print(eth1040)
print(eth1041)
print(eth1042)
print(eth1043)
print(eth1044)
print(eth1045)
print(eth1046)
print(eth1047)
print(eth1048)
print(eth1049)
print(eth1050)
print(eth1051)
print(eth1052)
print(eth1053)
print(eth1054)
print(eth1055)
print(eth1056)
print(eth1057)
print(eth1058)
print(eth1059)
print(eth1060)
print(eth1061)
print(eth1062)
print(eth1063)
print(eth1064)
print(eth1065)
print(eth1066)
print(eth1067)
print(eth1068)
print(eth1069)
print(eth1070)
print(eth1071)
print(eth1072)
print(eth1073)
print(eth1074)
print(eth1075)
print(eth1076)
print(eth1077)
print(eth1078)
print(eth1079)
print(eth1080)
print(eth1081)
print(eth1082)
print(eth1083)
print(eth1084)
print(eth1085)
print(eth1086)
print(eth1087)
print(eth1088)
print(eth1089)
print(eth1090)
print(eth1091)
print(eth1092)
print(eth1093)
print(eth1094)
print(eth1095)
print(eth1096)
print(eth1097)
print(eth1098)
print(eth1099)
print(eth1100)
print(eth1101)
print(eth1102)
print(eth1103)
print(eth1104)
print(eth1105)
print(eth1106)
print(eth1107)
print(eth1108)
print(eth1109)
print(eth1110)
print(eth1111)
print(eth1112)
print(eth1113)
print(eth1114)
print(eth1115)
print(eth1116)
print(eth1117)
print(eth1118)
print(eth1119)
print(eth1120)
print(eth1121)
print(eth1122)
print(eth1123)
print(eth1124)
print(eth1125)
print(eth1126)
print(eth1127)
print(eth1128)
print(eth1129)
print(eth1130)
print(eth1131)
print(eth1132)
print(eth1133)
print(eth1134)
print(eth1135)
print(eth1136)
print(eth1137)
print(eth1138)
print(eth1139)
print(eth1140)
print(eth1141)
print(eth1142)
print(eth1143)
print(eth1144)
print(eth1145)
print(eth1146)
print(eth1147)
print(eth1148)
print(eth1149)
print(eth1150)
print(eth1151)
print(eth1152)
print(eth1153)
print(eth1154)
print(eth1155)
print(eth1156)
print(eth1157)
print(eth1158)
print(eth1159)
print(eth1160)
print(eth1161)
print(eth1162)
print(eth1163)
print(eth1164)
print(eth1165)
print(eth1166)
print(eth1167)
print(eth1168)
print(eth1169)
print(eth1170)
print(eth1171)
print(eth1172)
print(eth1173)
print(eth1174)
print(eth1175)
print(eth1176)
print(eth1177)
print(eth1178)
print(eth1179)
print(eth1180)
print(eth1181)
print(eth1182)
print(eth1183)
print(eth1184)
print(eth1185)
print(eth1186)
print(eth1187)
print(eth1188)
print(eth1189)
print(eth1190)
print(eth1191)
print(eth1192)
print(eth1193)
print(eth1194)
print(eth1195)
print(eth1196)
print(eth1197)
print(eth1198)
print(eth1199)
print(eth1200)
print(eth1201)
print(eth1202)
print(eth1203)
print(eth1204)
print(eth1205)
print(eth1206)
print(eth1207)
print(eth1208)
print(eth1209)
print(eth1210)
print(eth1211)
print(eth1212)
print(eth1213)
print(eth1214)
print(eth1215)
print(eth1216)
print(eth1217)
print(eth1218)
print(eth1219)
print(eth1220)
print(eth1221)
print(eth1222)
print(eth1223)
print(eth1224)
print(eth1225)
print(eth1226)
print(eth1227)
print(eth1228)
print(eth1229)
print(eth1230)
print(eth1231)
print(eth1232)
print(eth1233)
print(eth1234)
print(eth1235)
print(eth1236)
print(eth1237)
print(eth1238)
print(eth1239)
print(eth1240)
print(eth1241)
print(eth1242)
print(eth1243)
print(eth1244)
print(eth1245)
print(eth1246)
print(eth1247)
print(eth1248)
print(eth1249)
print(eth1250)
print(eth1251)
print(eth1252)
print(eth1253)
print(eth1254)
print(eth1255)
print(eth1256)
print(eth1257)
print(eth1258)
print(eth1259)
print(eth1260)
print(eth1261)
# Out:
# 0x1AFc9bf43540a48FE062cbadFB8Ea9f302c63cF4
# 0x31e57B65B60a48b5C679d67991093c7737cB327D
# 0x73029536412d32449FB7135469368c65E3DBbE48
# 0x1E93441FE945e7aB2cEf198a2F51E0135E2CCf43
# 0xA81c01cF8768b75c674F698c4346446B87b898F4
# None
# 0x786785DD2011bF4ccF9271371f1104a461605a74
# 0x0653BA2FC838bb305BB434c79a0dEA216cfD7018
# 0x05F5773d93f76f6700f839dd406c4DdA2511Ca9B
# 0x06EB22d5ba034Ef08c5678e945f7998d44610451
# None
# None
# 0xA23a623F54b9688bB0941523cf3D821291d1442c
# 0x342C6BFA287CE37B8b53Eee0e5B6E6BCBeA98c76
# 0x807a9fA3CEDeC27CF5BdF4BD093fC2A92fc7be79
# 0x292E5e7BC7AE6C740fFbeA4971C388854Eee9Bd2
# 0xF81a57BE065F97Fe5dA1217144171cDEf9D88751
# 0x3197E832d4C097bEe6ADf7a9Ee84986BE64C0cFC
# 0xc6Fb342c707Fff164678c4163DdD8A1342fBBeFB
# None
# 0xd4BAe7060ECc2CEAb881033a74f770D78830D5a5
# 0x38B5fE7df5b9fD8bFc83696d9FB62475774A036e
# 0x4c677D46e5554BBd43Dcd7c0F571e6c28D5bC661
# 0x75e716639F2765515FB08707036Af958917e302E
# 0xFf6b585D0442a290Dbb9B03534Ecd463cdAF5970
# ...

# %%
eth01=	ns.owner('richard47.eth')
eth02=	ns.owner('richardcooper.eth')
eth03=	ns.owner('69richard.eth')
eth04=	ns.owner('richardryan.eth')
eth05=	ns.owner('richard508.eth')
eth06=	ns.owner('richardchi.eth')
eth07=	ns.owner('richard555.eth')
eth08=	ns.owner('richardderivative.eth')
eth09=	ns.owner('richard-mutt.eth')
eth010=	ns.owner('defirichard.eth')
eth011=	ns.owner('🤴richard.eth')
eth012=	ns.owner('arichardlaurent.eth')
eth013=	ns.owner('keithrichards.eth')
eth014=	ns.owner('richardcomedy.eth')
eth015=	ns.owner('richardrui.eth')
eth016=	ns.owner('richard400.eth')
eth017=	ns.owner('micahrichards.eth')
eth018=	ns.owner('princerichard.eth')
eth019=	ns.owner('richardface.eth')
eth020=	ns.owner('richarddixon.eth')
eth021=	ns.owner('richard®.eth')
eth022=	ns.owner('richardrichard.eth')
eth023=	ns.owner('richardpix.eth')
eth024=	ns.owner('chrisrichardson.eth')
eth025=	ns.owner('richardwiig.eth')
eth026=	ns.owner('richardent.eth')
eth027=	ns.owner('mrsrichard.eth')
eth028=	ns.owner('richardwatkins.eth')
eth029=	ns.owner('richardman.eth')
eth030=	ns.owner('not-richard.eth')
eth031=	ns.owner('richard113.eth')
eth032=	ns.owner('richard28.eth')
eth033=	ns.owner('richarddebas.eth')
eth034=	ns.owner('giverichard.eth')
eth035=	ns.owner('davidrichardson.eth')
eth036=	ns.owner('hairyrichard.eth')
eth037=	ns.owner('firstrichard.eth')
eth038=	ns.owner('richard68.eth')
eth039=	ns.owner('xrichardx.eth')
eth040=	ns.owner('richardsons.eth')
eth041=	ns.owner('richard925.eth')
eth042=	ns.owner('richard87.eth')
eth043=	ns.owner('richardmolloy.eth')
eth044=	ns.owner('richardmille3502.eth')
eth045=	ns.owner('papirichard.eth')
eth046=	ns.owner('richardslezak.eth')
eth047=	ns.owner('richard15.eth')
eth048=	ns.owner('0xrichard11.eth')
eth049=	ns.owner('richardgear.eth')
eth050=	ns.owner('easyrichard.eth')
eth051=	ns.owner('0xrichard.eth')
eth052=	ns.owner('ogrichard.eth')
eth053=	ns.owner('0xkingrichard.eth')
eth054=	ns.owner('richard110.eth')
eth055=	ns.owner('filthyrichard.eth')
eth056=	ns.owner('sarahrichards.eth')
eth057=	ns.owner('richard7.eth')
eth058=	ns.owner('stop-richarding.eth')
eth059=	ns.owner('richardbuu.eth')
eth060=	ns.owner('richardfinity.eth')
eth061=	ns.owner('richardu.eth')
eth062=	ns.owner('richardgiles.eth')
eth063=	ns.owner('richard-dao.eth')
eth064=	ns.owner('bedroomrichard.eth')
eth065=	ns.owner('skylarrichard.eth')
eth066=	ns.owner('litlerichard.eth')
eth067=	ns.owner('richard916.eth')
eth068=	ns.owner('richardyolo.eth')
eth069=	ns.owner('cbrichardellis.eth')
eth070=	ns.owner('rentarichard.eth')
eth071=	ns.owner('jamesrichardfry.eth')
eth072=	ns.owner('thelastrichard.eth')
eth073=	ns.owner('sendrichard.eth')
eth074=	ns.owner('richardprints.eth')
eth075=	ns.owner('richardsprague.eth')
eth076=	ns.owner('richardisme.eth')
eth077=	ns.owner('richard16.eth')
eth078=	ns.owner('totalrichard.eth')
eth079=	ns.owner('paulrichards.eth')
eth080=	ns.owner('zkrichard.eth')
eth081=	ns.owner('richard120.eth')
eth082=	ns.owner('steverichards.eth')
eth083=	ns.owner('sirrichardstarkeymberingostarr.eth')
eth084=	ns.owner('richardgarriott.eth')
eth085=	ns.owner('sirrichard.eth')
eth086=	ns.owner('richardlim.eth')
eth087=	ns.owner('richardliang.eth')
eth088=	ns.owner('richardgang.eth')
eth089=	ns.owner('richardfang.eth')
eth090=	ns.owner('whenrichardheartonbankless.eth')
eth091=	ns.owner('richardzphotoz.eth')
eth092=	ns.owner('ezrichard.eth')
eth093=	ns.owner('richardgarcia.eth')
eth094=	ns.owner('adamrichard.eth')
eth095=	ns.owner('richardgm.eth')
eth096=	ns.owner('richard91.eth')
eth097=	ns.owner('richardg.eth')
eth098=	ns.owner('richardcapital.eth')
eth099=	ns.owner('richard70.eth')
eth0100=	ns.owner('richardsburgers.eth')
eth0101=	ns.owner('richardma.eth')
eth0102=	ns.owner('richard2023.eth')
eth0103=	ns.owner('richard999.eth')
eth0104=	ns.owner('richard12.eth')
eth0105=	ns.owner('bigrichardenergy.eth')
eth0106=	ns.owner('richardtran.eth')
eth0107=	ns.owner('richardcheese.eth')
eth0108=	ns.owner('richierichard.eth')
eth0109=	ns.owner('richardgothits.eth')
eth0110=	ns.owner('richardtrickle.eth')
eth0111=	ns.owner('peperichard.eth')
eth0112=	ns.owner('richard102.eth')
eth0113=	ns.owner('goodrichard.eth')
eth0114=	ns.owner('richard-petty.eth')
eth0115=	ns.owner('richard19.eth')
eth0116=	ns.owner('richard26.eth')
eth0117=	ns.owner('degenrichard.eth')
eth0118=	ns.owner('jordanrichardson.eth')
eth0119=	ns.owner('richard02.eth')
eth0120=	ns.owner('makerichardgreatagain.eth')
eth0121=	ns.owner('richard500.eth')
eth0122=	ns.owner('richardalpert.eth')
eth0123=	ns.owner('no1richard.eth')
eth0124=	ns.owner('richardvandyke.eth')
eth0125=	ns.owner('richard914.eth')
eth0126=	ns.owner('whatthefuckrichard.eth')
eth0127=	ns.owner('cuckrichard.eth')
eth0128=	ns.owner('largerichard.eth')
eth0129=	ns.owner('spottedrichard.eth')
eth0130=	ns.owner('poorrichard.eth')
eth0131=	ns.owner('richardsonroyer.eth')
eth0132=	ns.owner('whiterichard.eth')
eth0133=	ns.owner('richardeddown.eth')
eth0134=	ns.owner('richardrosa.eth')
eth0135=	ns.owner('eatarichard.eth')
eth0136=	ns.owner('mommarichard.eth')
eth0137=	ns.owner('richard561.eth')
eth0138=	ns.owner('richardwagner.eth')
eth0139=	ns.owner('hardrichard.eth')
eth0140=	ns.owner('howrichard.eth')
eth0141=	ns.owner('richardson420.eth')
eth0142=	ns.owner('mrichard.eth')
eth0143=	ns.owner('richardcon.eth')
eth0144=	ns.owner('richardsimmons.eth')
eth0145=	ns.owner('richardvip.eth')
eth0146=	ns.owner('richardbertozzo.eth')
eth0147=	ns.owner('thankyourichard.eth')
eth0148=	ns.owner('richardgarner.eth')
eth0149=	ns.owner('richard747.eth')
eth0150=	ns.owner('jasonrrichardson.eth')
eth0151=	ns.owner('richard312.eth')
eth0152=	ns.owner('richardgov.eth')
eth0153=	ns.owner('hallofrichard.eth')
eth0154=	ns.owner('richrichard.eth')
eth0155=	ns.owner('richardmaris.eth')
eth0156=	ns.owner('richardless.eth')
eth0157=	ns.owner('richardbaker.eth')
eth0158=	ns.owner('ourrichard.eth')
eth0159=	ns.owner('richardxxx.eth')
eth0160=	ns.owner('i-richard.eth')
eth0161=	ns.owner('richard⚡.eth')
eth0162=	ns.owner('richard03.eth')
eth0163=	ns.owner('richardblevins.eth')
eth0164=	ns.owner('richard011.eth')
eth0165=	ns.owner('richardlicker.eth')
eth0166=	ns.owner('richard502.eth')
eth0167=	ns.owner('richarduy.eth')
eth0168=	ns.owner('richardjokes.eth')
eth0169=	ns.owner('slaprichard.eth')
eth0170=	ns.owner('richardrich.eth')
eth0171=	ns.owner('kevinrichardson.eth')
eth0172=	ns.owner('richard-bot.eth')
eth0173=	ns.owner('richardtracy.eth')
eth0174=	ns.owner('jprichardson.eth')
eth0175=	ns.owner('mrrichard.eth')
eth0176=	ns.owner('richard55.eth')
eth0177=	ns.owner('sithrichard.eth')
eth0178=	ns.owner('richardescobar.eth')
eth0179=	ns.owner('richardpay.eth')
eth0180=	ns.owner('richardwood.eth')
eth0181=	ns.owner('richardpicart.eth')
eth0182=	ns.owner('kylerichards.eth')
eth0183=	ns.owner('richardle.eth')
eth0184=	ns.owner('richardsimpson.eth')
eth0185=	ns.owner('richardjypark.eth')
eth0186=	ns.owner('rich-richer-richard.eth')
eth0187=	ns.owner('richard646.eth')
eth0188=	ns.owner('richardgod.eth')
eth0189=	ns.owner('richardmill.eth')
eth0190=	ns.owner('richarduranus.eth')
eth0191=	ns.owner('chickswithrichards.eth')
eth0192=	ns.owner('richarddjames.eth')
eth0193=	ns.owner('serrichard.eth')
eth0194=	ns.owner('otherrichard.eth')
eth0195=	ns.owner('wereallrichard.eth')
eth0196=	ns.owner('richardisgay.eth')
eth0197=	ns.owner('richardhendrix.eth')
eth0198=	ns.owner('richard504.eth')
eth0199=	ns.owner('richard62.eth')
eth0200=	ns.owner('richard27.eth')
eth0201=	ns.owner('richardcheung.eth')
eth0202=	ns.owner('richard31.eth')
eth0203=	ns.owner('jamesrichardson.eth')
eth0204=	ns.owner('gotrichard.eth')
eth0205=	ns.owner('richardhard.eth')
eth0206=	ns.owner('richarde.eth')
eth0207=	ns.owner('richardjkunz.eth')
eth0208=	ns.owner('richardb.eth')
eth0209=	ns.owner('richardshan.eth')
eth0210=	ns.owner('samrichards.eth')
eth0211=	ns.owner('richardbot.eth')
eth0212=	ns.owner('richard75.eth')
eth0213=	ns.owner('chadrichard.eth')
eth0214=	ns.owner('richardoh.eth')
eth0215=	ns.owner('richard42.eth')
eth0216=	ns.owner('dukerichard.eth')
eth0217=	ns.owner('richardroche.eth')
eth0218=	ns.owner('richard125.eth')
eth0219=	ns.owner('anti-richard.eth')
eth0220=	ns.owner('keithrichard.eth')
eth0221=	ns.owner('mr-richard.eth')
eth0222=	ns.owner('richardricardo.eth')
eth0223=	ns.owner('richard333.eth')
eth0224=	ns.owner('richard25.eth')
eth0225=	ns.owner('richardlee.eth')
eth0226=	ns.owner('berichard.eth')
eth0227=	ns.owner('richard917.eth')
eth0228=	ns.owner('richardhomer.eth')
eth0229=	ns.owner('richardaf.eth')
eth0230=	ns.owner('pimprichard.eth')
eth0231=	ns.owner('richard509.eth')
eth0232=	ns.owner('richardnoggin.eth')
eth0233=	ns.owner('richardsmom.eth')
eth0234=	ns.owner('therichards.eth')
eth0235=	ns.owner('joerichard.eth')
eth0236=	ns.owner('prichard.eth')
eth0237=	ns.owner('richardasfuck.eth')
eth0238=	ns.owner('richardyu.eth')
eth0239=	ns.owner('richard107.eth')
eth0240=	ns.owner('richard06.eth')
eth0241=	ns.owner('richard11.eth')
eth0242=	ns.owner('richardjpeg.eth')
eth0243=	ns.owner('richard71.eth')
eth0244=	ns.owner('richard777.eth')
eth0245=	ns.owner('richardball.eth')
eth0246=	ns.owner('richardsen.eth')
eth0247=	ns.owner('richardette.eth')
eth0248=	ns.owner('richard202.eth')
eth0249=	ns.owner('richard8.eth')
eth0250=	ns.owner('little-richard.eth')
eth0251=	ns.owner('wenrichard.eth')
eth0252=	ns.owner('richardick.eth')
eth0253=	ns.owner('richardandmorty.eth')
eth0254=	ns.owner('richardbuettner.eth')
eth0255=	ns.owner('richard51.eth')
eth0256=	ns.owner('picklerichard.eth')
eth0257=	ns.owner('richard👑.eth')
eth0258=	ns.owner('richardgage911.eth')
eth0259=	ns.owner('richardmille-official.eth')
eth0260=	ns.owner('richestrichard.eth')
eth0261=	ns.owner('richardinu.eth')
eth0262=	ns.owner('richardkelley.eth')
eth0263=	ns.owner('megarichard.eth')
eth0264=	ns.owner('🧟‍♂richard.eth')
eth0265=	ns.owner('richardcheney.eth')
eth0266=	ns.owner('richardavery.eth')
eth0267=	ns.owner('richardsanchez.eth')
eth0268=	ns.owner('richardorlinski.eth')
eth0269=	ns.owner('richardsenior.eth')
eth0270=	ns.owner('jackrichardson.eth')
eth0271=	ns.owner('richardbuterin.eth')
eth0272=	ns.owner('richardmuljadi.eth')
eth0273=	ns.owner('johnrichards.eth')
eth0274=	ns.owner('richardsaghian.eth')
eth0275=	ns.owner('kidrichard.eth')
eth0276=	ns.owner('richardlindsay.eth')
eth0277=	ns.owner('rrrichard.eth')
eth0278=	ns.owner('babyrichard.eth')
eth0279=	ns.owner('dickrichard.eth')
eth0280=	ns.owner('richard🦁🫀.eth')
eth0281=	ns.owner('clubrichard.eth')
eth0282=	ns.owner('discordrichard.eth')
eth0283=	ns.owner('richardmutt.eth')
eth0284=	ns.owner('richardpaul.eth')
eth0285=	ns.owner('richardblue.eth')
eth0286=	ns.owner('richardlovelace.eth')
eth0287=	ns.owner('richardology.eth')
eth0288=	ns.owner('richardlewis.eth')
eth0289=	ns.owner('richardverse.eth')
eth0290=	ns.owner('richardlevin.eth')
eth0291=	ns.owner('richard0.eth')
eth0292=	ns.owner('richardnoun.eth')
eth0293=	ns.owner('longhardrichard.eth')
eth0294=	ns.owner('richardn.eth')
eth0295=	ns.owner('richard808.eth')
eth0296=	ns.owner('richardx.eth')
eth0297=	ns.owner('richardbtc.eth')
eth0298=	ns.owner('richarda.eth')
eth0299=	ns.owner('richardxhe.eth')
eth0300=	ns.owner('mrichards.eth')
eth0301=	ns.owner('richardinya.eth')
eth0302=	ns.owner('richardtaylor.eth')
eth0303=	ns.owner('richardhadlee.eth')
eth0304=	ns.owner('regular-richard.eth')
eth0305=	ns.owner('richardwallet.eth')
eth0306=	ns.owner('richard124.eth')
eth0307=	ns.owner('richardegrant.eth')
eth0308=	ns.owner('richard2.eth')
eth0309=	ns.owner('cliffrichard.eth')
eth0310=	ns.owner('richardwolf.eth')
eth0311=	ns.owner('richardkim.eth')
eth0312=	ns.owner('irichard.eth')
eth0313=	ns.owner('richardvagner.eth')
eth0314=	ns.owner('richard2022.eth')
eth0315=	ns.owner('richardrock.eth')
eth0316=	ns.owner('richard40.eth')
eth0317=	ns.owner('richardbspencer.eth')
eth0318=	ns.owner('richardsweat.eth')
eth0319=	ns.owner('pernod-richard.eth')
eth0320=	ns.owner('richardoostra.eth')
eth0321=	ns.owner('richardcrookes.eth')
eth0322=	ns.owner('richardrauser.eth')
eth0323=	ns.owner('1-richard.eth')
eth0324=	ns.owner('richardgere.eth')
eth0325=	ns.owner('richardanderson.eth')
eth0326=	ns.owner('richardtodosichuk.eth')
eth0327=	ns.owner('richardisgod.eth')
eth0328=	ns.owner('richarddawkins.eth')
eth0329=	ns.owner('richardpics.eth')
eth0330=	ns.owner('richardofeth.eth')
eth0331=	ns.owner('jaredrichardson.eth')
eth0332=	ns.owner('richardsullivan.eth')
eth0333=	ns.owner('richardtravis.eth')
eth0334=	ns.owner('richardmiranda.eth')
eth0335=	ns.owner('blakerichardson.eth')
eth0336=	ns.owner('presidentrichardnixon.eth')
eth0337=	ns.owner('richardnguyen.eth')
eth0338=	ns.owner('richard56.eth')
eth0339=	ns.owner('thesearenottherichardsyouarelookingfor.eth')
eth0340=	ns.owner('richardmnixon.eth')
eth0341=	ns.owner('ceorichard.eth')
eth0342=	ns.owner('richardcrypto.eth')
eth0343=	ns.owner('richardesque.eth')
eth0344=	ns.owner('fuckyourichard.eth')
eth0345=	ns.owner('richardsucks.eth')
eth0346=	ns.owner('richardnixon.eth')
eth0347=	ns.owner('saintrichard.eth')
eth0348=	ns.owner('richardassaf.eth')
eth0349=	ns.owner('richardfairbank.eth')
eth0350=	ns.owner('richardish.eth')
eth0351=	ns.owner('fuckingrichard.eth')
eth0352=	ns.owner('madisonrichards.eth')
eth0353=	ns.owner('richardmccrae.eth')
eth0354=	ns.owner('888richard.eth')
eth0355=	ns.owner('sirrichardbranson.eth')
eth0356=	ns.owner('richard3d7.eth')
eth0357=	ns.owner('trichardson.eth')
eth0358=	ns.owner('richard669.eth')
eth0359=	ns.owner('richard002.eth')
eth0360=	ns.owner('richard-millie.eth')
eth0361=	ns.owner('lionheartrichard.eth')
eth0362=	ns.owner('nftrichard.eth')
eth0363=	ns.owner('cuckoldrichard.eth')
eth0364=	ns.owner('richard111.eth')
eth0365=	ns.owner('me-richard.eth')
eth0366=	ns.owner('richard707.eth')
eth0367=	ns.owner('richardparayno.eth')
eth0368=	ns.owner('iamrichard.eth')
eth0369=	ns.owner('richard23.eth')
eth0370=	ns.owner('richard899.eth')
eth0371=	ns.owner('killrichard.eth')
eth0372=	ns.owner('richard34.eth')
eth0373=	ns.owner('deniserichards.eth')
eth0374=	ns.owner('richard-official.eth')
eth0375=	ns.owner('richardgarfield.eth')
eth0376=	ns.owner('erectrichard.eth')
eth0377=	ns.owner('richardrichardrichard.eth')
eth0378=	ns.owner('richardandballs.eth')
eth0379=	ns.owner('theodorerichards.eth')
eth0380=	ns.owner('bestrichard.eth')
eth0381=	ns.owner('codyrichards.eth')
eth0382=	ns.owner('richardcoin.eth')
eth0383=	ns.owner('richardhouse.eth')
eth0384=	ns.owner('richard24.eth')
eth0385=	ns.owner('africanrichard.eth')
eth0386=	ns.owner('richardjr.eth')
eth0387=	ns.owner('richard🔥.eth')
eth0388=	ns.owner('richardalderson.eth')
eth0389=	ns.owner('merichard.eth')
eth0390=	ns.owner('richardbranson.eth')
eth0391=	ns.owner('0x👑richard.eth')
eth0392=	ns.owner('richard45.eth')
eth0393=	ns.owner('ohrichard.eth')
eth0394=	ns.owner('richardraizes.eth')
eth0395=	ns.owner('richard301.eth')
eth0396=	ns.owner('richard303.eth')
eth0397=	ns.owner('charichard.eth')
eth0398=	ns.owner('toprichard.eth')
eth0399=	ns.owner('run-richard-run.eth')
eth0400=	ns.owner('richard35.eth')
eth0401=	ns.owner('richard713.eth')
eth0402=	ns.owner('richardbonilla.eth')
eth0403=	ns.owner('richardliu.eth')
eth0404=	ns.owner('richardwhite.eth')
eth0405=	ns.owner('richard🍆.eth')
eth0406=	ns.owner('jsrichards.eth')
eth0407=	ns.owner('richardbengston.eth')
eth0408=	ns.owner('richardtom.eth')
eth0409=	ns.owner('richardispeace.eth')
eth0410=	ns.owner('1richard.eth')
eth0411=	ns.owner('richarding.eth')
eth0412=	ns.owner('richardbirch.eth')
eth0413=	ns.owner('richardmfer.eth')
eth0414=	ns.owner('🏴‍☠richard.eth')
eth0415=	ns.owner('richard44.eth')
eth0416=	ns.owner('richard0x.eth')
eth0417=	ns.owner('richardmilledao.eth')
eth0418=	ns.owner('richardwilson.eth')
eth0419=	ns.owner('richardadada.eth')
eth0420=	ns.owner('richardhendricks.eth')
eth0421=	ns.owner('carlrichards.eth')
eth0422=	ns.owner('gigarichard.eth')
eth0423=	ns.owner('minirichard.eth')
eth0424=	ns.owner('richardlovescrypto.eth')
eth0425=	ns.owner('richardhubbard.eth')
eth0426=	ns.owner('richardmille®.eth')
eth0427=	ns.owner('richardsherman.eth')
eth0428=	ns.owner('richardjacobs.eth')
eth0429=	ns.owner('richard123.eth')
eth0430=	ns.owner('richard369.eth')
eth0431=	ns.owner('richardbruskoff.eth')
eth0432=	ns.owner('richardf.eth')
eth0433=	ns.owner('richardswallet.eth')
eth0434=	ns.owner('richardovic.eth')
eth0435=	ns.owner('richardrichardson.eth')
eth0436=	ns.owner('richard.eth')
eth0437=	ns.owner('richardthethird.eth')
eth0438=	ns.owner('vitalikrichardin.eth')
eth0439=	ns.owner('masterrichard.eth')
eth0440=	ns.owner('richardrekt.eth')
eth0441=	ns.owner('jrichard.eth')
eth0442=	ns.owner('richard50.eth')
eth0443=	ns.owner('richard109.eth')
eth0444=	ns.owner('remember-richard.eth')
eth0445=	ns.owner('big-richard.eth')
eth0446=	ns.owner('mobyrichard.eth')
eth0447=	ns.owner('richardcranium.eth')
eth0448=	ns.owner('londonrichards.eth')
eth0449=	ns.owner('richardiv.eth')
eth0450=	ns.owner('richard-mille.eth')
eth0451=	ns.owner('richardporn.eth')
eth0452=	ns.owner('richardreserve.eth')
eth0453=	ns.owner('richardfraser.eth')
eth0454=	ns.owner('richardc.eth')
eth0455=	ns.owner('richard1.eth')
eth0456=	ns.owner('richardsday.eth')
eth0457=	ns.owner('king-richard.eth')
eth0458=	ns.owner('markrichardson.eth')
eth0459=	ns.owner('richardgoodwin.eth')
eth0460=	ns.owner('richardashe.eth')
eth0461=	ns.owner('richard86.eth')
eth0462=	ns.owner('richard3000.eth')
eth0463=	ns.owner('richardburke.eth')
eth0464=	ns.owner('mcrichardface.eth')
eth0465=	ns.owner('arichard.eth')
eth0466=	ns.owner('fish-richardson.eth')
eth0467=	ns.owner('richardhole.eth')
eth0468=	ns.owner('richardandthesorcerersstone.eth')
eth0469=	ns.owner('richard-the-turd.eth')
eth0470=	ns.owner('victoriarichardson.eth')
eth0471=	ns.owner('richardthrasher.eth')
eth0472=	ns.owner('e-richard.eth')
eth0473=	ns.owner('lionelrichard.eth')
eth0474=	ns.owner('kimrichards.eth')
eth0475=	ns.owner('richardhennessy.eth')
eth0476=	ns.owner('drrichard.eth')
eth0477=	ns.owner('richardanthony.eth')
eth0478=	ns.owner('richardtown.eth')
eth0479=	ns.owner('karenrichard.eth')
eth0480=	ns.owner('ensrichard.eth')
eth0481=	ns.owner('richard112.eth')
eth0482=	ns.owner('skylarlrichards.eth')
eth0483=	ns.owner('richard-gere.eth')
eth0484=	ns.owner('richard858.eth')
eth0485=	ns.owner('richard444.eth')
eth0486=	ns.owner('therichrichard.eth')
eth0487=	ns.owner('richardpilnick.eth')
eth0488=	ns.owner('richardbeauregard.eth')
eth0489=	ns.owner('richardbirse.eth')
eth0490=	ns.owner('richard01.eth')
eth0491=	ns.owner('u-richard.eth')
eth0492=	ns.owner('richardkelly.eth')
eth0493=	ns.owner('richard32.eth')
eth0494=	ns.owner('drprichard.eth')
eth0495=	ns.owner('magicrichard.eth')
eth0496=	ns.owner('ohrichardimsohappyholdme.eth')
eth0497=	ns.owner('richardism.eth')
eth0498=	ns.owner('richardxu.eth')
eth0499=	ns.owner('richard-wallet.eth')
eth0500=	ns.owner('officialrichard.eth')
eth0501=	ns.owner('richardkang.eth')
eth0502=	ns.owner('richard411.eth')
eth0503=	ns.owner('richardking.eth')
eth0504=	ns.owner('richardmichaeljordan.eth')
eth0505=	ns.owner('richardayoade.eth')
eth0506=	ns.owner('richardnie.eth')
eth0507=	ns.owner('richard2024.eth')
eth0508=	ns.owner('richard-club.eth')
eth0509=	ns.owner('richardmarken.eth')
eth0510=	ns.owner('richardcan.eth')
eth0511=	ns.owner('maryrichards.eth')
eth0512=	ns.owner('rocketrichard.eth')
eth0513=	ns.owner('richard82.eth')
eth0514=	ns.owner('richardy.eth')
eth0515=	ns.owner('originalrichard.eth')
eth0516=	ns.owner('richardlam.eth')
eth0517=	ns.owner('fishrichardson.eth')
eth0518=	ns.owner('richard222.eth')
eth0519=	ns.owner('the-real-richard.eth')
eth0520=	ns.owner('richard117.eth')
eth0521=	ns.owner('nathanielrichard.eth')
eth0522=	ns.owner('richardchan.eth')
eth0523=	ns.owner('richardfamily.eth')
eth0524=	ns.owner('richardcity.eth')
eth0525=	ns.owner('richard69.eth')
eth0526=	ns.owner('richardinabox.eth')
eth0527=	ns.owner('richard305.eth')
eth0528=	ns.owner('richard900.eth')
eth0529=	ns.owner('richarddao.eth')
eth0530=	ns.owner('terrellrichardson.eth')
eth0531=	ns.owner('richardmille-watches.eth')
eth0532=	ns.owner('richard13.eth')
eth0533=	ns.owner('boredrichard.eth')
eth0534=	ns.owner('richard760.eth')
eth0535=	ns.owner('richardthe🦁🫀.eth')
eth0536=	ns.owner('richardolowe.eth')
eth0537=	ns.owner('richard90.eth')
eth0538=	ns.owner('timrichardson.eth')
eth0539=	ns.owner('richardaldana.eth')
eth0540=	ns.owner('oldrichard.eth')
eth0541=	ns.owner('snooprichard.eth')
eth0542=	ns.owner('therichard.eth')
eth0543=	ns.owner('payrichard.eth')
eth0544=	ns.owner('richardkirkendall.eth')
eth0545=	ns.owner('richardholdings.eth')
eth0546=	ns.owner('richardcock.eth')
eth0547=	ns.owner('skinnyrichard.eth')
eth0548=	ns.owner('richardjones.eth')
eth0549=	ns.owner('richard650.eth')
eth0550=	ns.owner('richard631.eth')
eth0551=	ns.owner('rockhardrichard.eth')
eth0552=	ns.owner('richardbutkus.eth')
eth0553=	ns.owner('richardingo.eth')
eth0554=	ns.owner('mikerichard.eth')
eth0555=	ns.owner('🇺🇸richard.eth')
eth0556=	ns.owner('richard37.eth')
eth0557=	ns.owner('richardcantillon.eth')
eth0558=	ns.owner('thanksrichard.eth')
eth0559=	ns.owner('whoisrichard.eth')
eth0560=	ns.owner('richardgreat.eth')
eth0561=	ns.owner('richardlionheart.eth')
eth0562=	ns.owner('richardville.eth')
eth0563=	ns.owner('boredrichardyachtclub.eth')
eth0564=	ns.owner('👑richard👑.eth')
eth0565=	ns.owner('richard206.eth')
eth0566=	ns.owner('drreedrichards.eth')
eth0567=	ns.owner('richard95.eth')
eth0568=	ns.owner('inviterichardheartonbankless.eth')
eth0569=	ns.owner('richard269.eth')
eth0570=	ns.owner('richardyoo.eth')
eth0571=	ns.owner('richard313.eth')
eth0572=	ns.owner('richardians.eth')
eth0573=	ns.owner('richard48.eth')
eth0574=	ns.owner('richard789.eth')
eth0575=	ns.owner('123richard.eth')
eth0576=	ns.owner('richardjay.eth')
eth0577=	ns.owner('moonrichard.eth')
eth0578=	ns.owner('mynameisrichard.eth')
eth0579=	ns.owner('onlyrichard.eth')
eth0580=	ns.owner('richardfeynman.eth')
eth0581=	ns.owner('richard949.eth')
eth0582=	ns.owner('richard503.eth')
eth0583=	ns.owner('richardignacio.eth')
eth0584=	ns.owner('richard666.eth')
eth0585=	ns.owner('richardashcroft.eth')
eth0586=	ns.owner('richardsdad.eth')
eth0587=	ns.owner('richardhenne.eth')
eth0588=	ns.owner('wearerichard.eth')
eth0589=	ns.owner('richard59.eth')
eth0590=	ns.owner('richard006.eth')
eth0591=	ns.owner('richard😎.eth')
eth0592=	ns.owner('justrichard.eth')
eth0593=	ns.owner('amandauprichard.eth')
eth0594=	ns.owner('richardfoo.eth')
eth0595=	ns.owner('letsgetricharded.eth')
eth0596=	ns.owner('eserichard.eth')
eth0597=	ns.owner('richardheartwin.eth')
eth0598=	ns.owner('doctorrichard.eth')
eth0599=	ns.owner('richardspencer.eth')
eth0600=	ns.owner('richardcraib.eth')
eth0601=	ns.owner('richardwhatshappening.eth')
eth0602=	ns.owner('metarichard.eth')
eth0603=	ns.owner('richardweb3.eth')
eth0604=	ns.owner('richard213.eth')
eth0605=	ns.owner('richard260.eth')
eth0606=	ns.owner('askrichard.eth')
eth0607=	ns.owner('richardfernandes.eth')
eth0608=	ns.owner('cryptorichard.eth')
eth0609=	ns.owner('richardatkins.eth')
eth0610=	ns.owner('anonrichard.eth')
eth0611=	ns.owner('richard512.eth')
eth0612=	ns.owner('richardbeard.eth')
eth0613=	ns.owner('wtfrichard.eth')
eth0614=	ns.owner('richardd.eth')
eth0615=	ns.owner('therichardsons.eth')
eth0616=	ns.owner('everybodylovesrichard.eth')
eth0617=	ns.owner('richardsu.eth')
eth0618=	ns.owner('richardskelhorn.eth')
eth0619=	ns.owner('richard89.eth')
eth0620=	ns.owner('richardmusk.eth')
eth0621=	ns.owner('richard58.eth')
eth0622=	ns.owner('richard1000.eth')
eth0623=	ns.owner('richard562.eth')
eth0624=	ns.owner('richardo.eth')
eth0625=	ns.owner('richard101.eth')
eth0626=	ns.owner('anitarichard.eth')
eth0627=	ns.owner('richard737.eth')
eth0628=	ns.owner('richardwright.eth')
eth0629=	ns.owner('simplyrichard.eth')
eth0630=	ns.owner('richardchoi.eth')
eth0631=	ns.owner('richardq.eth')
eth0632=	ns.owner('richardchildressracing.eth')
eth0633=	ns.owner('richardsun.eth')
eth0634=	ns.owner('richard114.eth')
eth0635=	ns.owner('richardoo.eth')
eth0636=	ns.owner('richard17.eth')
eth0637=	ns.owner('hellorichard.eth')
eth0638=	ns.owner('richardsjewelry.eth')
eth0639=	ns.owner('richard404.eth')
eth0640=	ns.owner('richard14.eth')
eth0641=	ns.owner('richardbaxter.eth')
eth0642=	ns.owner('richardonmymind.eth')
eth0643=	ns.owner('jeffrichards.eth')
eth0644=	ns.owner('suckerichard.eth')
eth0645=	ns.owner('richardswole.eth')
eth0646=	ns.owner('richardiskevin.eth')
eth0647=	ns.owner('imrichard.eth')
eth0648=	ns.owner('richardistan.eth')
eth0649=	ns.owner('richardyuze.eth')
eth0650=	ns.owner('chubbyrichard.eth')
eth0651=	ns.owner('richardhammond.eth')
eth0652=	ns.owner('🔥richard.eth')
eth0653=	ns.owner('paparichard.eth')
eth0654=	ns.owner('notrichard.eth')
eth0655=	ns.owner('richarditait.eth')
eth0656=	ns.owner('richard911.eth')
eth0657=	ns.owner('richard04.eth')
eth0658=	ns.owner('richardmoon.eth')
eth0659=	ns.owner('richard069.eth')
eth0660=	ns.owner('richard60.eth')
eth0661=	ns.owner('kellyrichardson.eth')
eth0662=	ns.owner('richardhung.eth')
eth0663=	ns.owner('richard97.eth')
eth0664=	ns.owner('richardmeme.eth')
eth0665=	ns.owner('richardsex.eth')
eth0666=	ns.owner('richardian.eth')
eth0667=	ns.owner('letsgorichard.eth')
eth0668=	ns.owner('richard9999.eth')
eth0669=	ns.owner('richard1st.eth')
eth0670=	ns.owner('richardcaring.eth')
eth0671=	ns.owner('terryrichardson.eth')
eth0672=	ns.owner('majorrichard.eth')
eth0673=	ns.owner('lordrichard.eth')
eth0674=	ns.owner('richardbillyham.eth')
eth0675=	ns.owner('persianrichard.eth')
eth0676=	ns.owner('tallrichard.eth')
eth0677=	ns.owner('fuckrichard.eth')
eth0678=	ns.owner('richardzhi.eth')
eth0679=	ns.owner('littlerichard.eth')
eth0680=	ns.owner('richardr.eth')
eth0681=	ns.owner('bigdickrichard.eth')
eth0682=	ns.owner('richardsummer.eth')
eth0683=	ns.owner('richard93.eth')
eth0684=	ns.owner('richardtm.eth')
eth0685=	ns.owner('richardmillie.eth')
eth0686=	ns.owner('bestrichardever.eth')
eth0687=	ns.owner('richard151.eth')
eth0688=	ns.owner('richardese.eth')
eth0689=	ns.owner('richard1111.eth')
eth0690=	ns.owner('richardsocher.eth')
eth0691=	ns.owner('richardsucker.eth')
eth0692=	ns.owner('richard247.eth')
eth0693=	ns.owner('richard007.eth')
eth0694=	ns.owner('smartrichard.eth')
eth0695=	ns.owner('richard85.eth')
eth0696=	ns.owner('richardrahcir.eth')
eth0697=	ns.owner('gregrichardson.eth')
eth0698=	ns.owner('billrichards.eth')
eth0699=	ns.owner('richardkimble.eth')
eth0700=	ns.owner('richardbro.eth')
eth0701=	ns.owner('richardbirds.eth')
eth0702=	ns.owner('richardmother.eth')
eth0703=	ns.owner('bagofrichards.eth')
eth0704=	ns.owner('mikerichardson.eth')
eth0705=	ns.owner('asianrichard.eth')
eth0706=	ns.owner('philrichards.eth')
eth0707=	ns.owner('😎richard.eth')
eth0708=	ns.owner('richardng.eth')
eth0709=	ns.owner('richardwashere.eth')
eth0710=	ns.owner('richardforpres.eth')
eth0711=	ns.owner('alpharichard.eth')
eth0712=	ns.owner('richardkastelein.eth')
eth0713=	ns.owner('richard52.eth')
eth0714=	ns.owner('richardmoore.eth')
eth0715=	ns.owner('richardmilleofficial.eth')
eth0716=	ns.owner('richardbui.eth')
eth0717=	ns.owner('richarddoteth.eth')
eth0718=	ns.owner('richardblack.eth')
eth0719=	ns.owner('richardsonexcavating.eth')
eth0720=	ns.owner('richardm.eth')
eth0721=	ns.owner('richardstroker.eth')
eth0722=	ns.owner('daddyrichard.eth')
eth0723=	ns.owner('cherryrichardson.eth')
eth0724=	ns.owner('jeanrichard.eth')
eth0725=	ns.owner('myrichard.eth')
eth0726=	ns.owner('trickyrichard.eth')
eth0727=	ns.owner('richard212.eth')
eth0728=	ns.owner('richardw.eth')
eth0729=	ns.owner('richardphd.eth')
eth0730=	ns.owner('nathanielrichards.eth')
eth0731=	ns.owner('richard83.eth')
eth0732=	ns.owner('harryrichard.eth')
eth0733=	ns.owner('richardooing.eth')
eth0734=	ns.owner('misterrichard.eth')
eth0735=	ns.owner('richardlean.eth')
eth0736=	ns.owner('colerichards.eth')
eth0737=	ns.owner('richardheart.eth')
eth0738=	ns.owner('richardfi.eth')
eth0739=	ns.owner('famousrichard.eth')
eth0740=	ns.owner('poorrichardsalmanack.eth')
eth0741=	ns.owner('suckerrichard.eth')
eth0742=	ns.owner('pricerichardson.eth')
eth0743=	ns.owner('richardquesto.eth')
eth0744=	ns.owner('piraterichard.eth')
eth0745=	ns.owner('richardisacunt.eth')
eth0746=	ns.owner('localrichard.eth')
eth0747=	ns.owner('hyperrichard.eth')
eth0748=	ns.owner('whatarichard.eth')
eth0749=	ns.owner('richard96.eth')
eth0750=	ns.owner('xrichard.eth')
eth0751=	ns.owner('aderichards.eth')
eth0752=	ns.owner('thebestrichardever.eth')
eth0753=	ns.owner('richardchang.eth')
eth0754=	ns.owner('mutantrichard.eth')
eth0755=	ns.owner('richardhobbs.eth')
eth0756=	ns.owner('toddrichards.eth')
eth0757=	ns.owner('richardolsen.eth')
eth0758=	ns.owner('nicerichard.eth')
eth0759=	ns.owner('roxyrichardson.eth')
eth0760=	ns.owner('brokerichard.eth')
eth0761=	ns.owner('richard116.eth')
eth0762=	ns.owner('joshrichards.eth')
eth0763=	ns.owner('dick-richard.eth')
eth0764=	ns.owner('richardramos.eth')
eth0765=	ns.owner('harryrichardson.eth')
eth0766=	ns.owner('viprichard.eth')
eth0767=	ns.owner('richardli.eth')
eth0768=	ns.owner('richardpetty.eth')
eth0769=	ns.owner('richard22.eth')
eth0770=	ns.owner('richard106.eth')
eth0771=	ns.owner('richardsatoshi.eth')
eth0772=	ns.owner('semirichard.eth')
eth0773=	ns.owner('richard008.eth')
eth0774=	ns.owner('tworichards.eth')
eth0775=	ns.owner('richardus.eth')
eth0776=	ns.owner('bluechiprichard.eth')
eth0777=	ns.owner('richard63.eth')
eth0778=	ns.owner('richard29.eth')
eth0779=	ns.owner('richardbeer.eth')
eth0780=	ns.owner('darthrichard.eth')
eth0781=	ns.owner('richard77.eth')
eth0782=	ns.owner('toririchard.eth')
eth0783=	ns.owner('roborichard.eth')
eth0784=	ns.owner('dashiellrichard.eth')
eth0785=	ns.owner('richard108.eth')
eth0786=	ns.owner('presidentrichard.eth')
eth0787=	ns.owner('richard33.eth')
eth0788=	ns.owner('richardyong.eth')
eth0789=	ns.owner('midrichard.eth')
eth0790=	ns.owner('westleyrichards.eth')
eth0791=	ns.owner('brichard.eth')
eth0792=	ns.owner('richard6.eth')
eth0793=	ns.owner('imnotrichard.eth')
eth0794=	ns.owner('richardmille.eth')
eth0795=	ns.owner('richardkettleborough.eth')
eth0796=	ns.owner('richardurex.eth')
eth0797=	ns.owner('vivrichards.eth')
eth0798=	ns.owner('richardbrautigan.eth')
eth0799=	ns.owner('unclerichard.eth')
eth0800=	ns.owner('hornyrichard.eth')
eth0801=	ns.owner('richard317.eth')
eth0802=	ns.owner('richard314.eth')
eth0803=	ns.owner('richardii.eth')
eth0804=	ns.owner('richardthefirst.eth')
eth0805=	ns.owner('dalerichardson.eth')
eth0806=	ns.owner('richard000.eth')
eth0807=	ns.owner('rerichard.eth')
eth0808=	ns.owner('richard700.eth')
eth0809=	ns.owner('richard-richard.eth')
eth0810=	ns.owner('richard711.eth')
eth0811=	ns.owner('richardnft.eth')
eth0812=	ns.owner('richard88.eth')
eth0813=	ns.owner('richarddavies.eth')
eth0814=	ns.owner('richardz.eth')
eth0815=	ns.owner('richardthegreat.eth')
eth0816=	ns.owner('earlyrichard.eth')
eth0817=	ns.owner('raunchyrichard.eth')
eth0818=	ns.owner('richard49.eth')
eth0819=	ns.owner('richardsondackam.eth')
eth0820=	ns.owner('richard©.eth')
eth0821=	ns.owner('richardist.eth')
eth0822=	ns.owner('richarder.eth')
eth0823=	ns.owner('richardrobson.eth')
eth0824=	ns.owner('richardi.eth')
eth0825=	ns.owner('richard69420.eth')
eth0826=	ns.owner('richard103.eth')
eth0827=	ns.owner('richardmemes.eth')
eth0828=	ns.owner('richardsauce.eth')
eth0829=	ns.owner('richardblankenship.eth')
eth0830=	ns.owner('richard270.eth')
eth0831=	ns.owner('richard121.eth')
eth0832=	ns.owner('arabicrichard.eth')
eth0833=	ns.owner('richard469.eth')
eth0834=	ns.owner('richardwilliams.eth')
eth0835=	ns.owner('richardiam.eth')
eth0836=	ns.owner('ruggedrichard.eth')
eth0837=	ns.owner('newrichard.eth')
eth0838=	ns.owner('richardmiles.eth')
eth0839=	ns.owner('pepe-richard.eth')
eth0840=	ns.owner('richard41.eth')
eth0841=	ns.owner('tylerjrichards.eth')
eth0842=	ns.owner('richardbrothers.eth')
eth0843=	ns.owner('stephenrichardson.eth')
eth0844=	ns.owner('richard61.eth')
eth0845=	ns.owner('richard21.eth')
eth0846=	ns.owner('freerichard.eth')
eth0847=	ns.owner('blockrichard.eth')
eth0848=	ns.owner('richardjoke.eth')
eth0849=	ns.owner('richardfather.eth')
eth0850=	ns.owner('buymorerichard.eth')
eth0851=	ns.owner('richardrupp.eth')
eth0852=	ns.owner('limprichard.eth')
eth0853=	ns.owner('richardvault.eth')
eth0854=	ns.owner('richardinho.eth')
eth0855=	ns.owner('richardest.eth')
eth0856=	ns.owner('richardbay.eth')
eth0857=	ns.owner('richard619.eth')
eth0858=	ns.owner('richardthe1st.eth')
eth0859=	ns.owner('drewrichards.eth')
eth0860=	ns.owner('richardpill.eth')
eth0861=	ns.owner('richardpenner.eth')
eth0862=	ns.owner('richard009.eth')
eth0863=	ns.owner('shanerichardson.eth')
eth0864=	ns.owner('richard6969.eth')
eth0865=	ns.owner('richard57.eth')
eth0866=	ns.owner('richardmadden.eth')
eth0867=	ns.owner('richard310.eth')
eth0868=	ns.owner('okayrichard.eth')
eth0869=	ns.owner('richardson.eth')
eth0870=	ns.owner('gnarichard.eth')
eth0871=	ns.owner('richard4k.eth')
eth0872=	ns.owner('richard004.eth')
eth0873=	ns.owner('richardia.eth')
eth0874=	ns.owner('richard332.eth')
eth0875=	ns.owner('crazyrichard.eth')
eth0876=	ns.owner('mattrichards.eth')
eth0877=	ns.owner('richardjackson.eth')
eth0878=	ns.owner('richardlong.eth')
eth0879=	ns.owner('richardroberts.eth')
eth0880=	ns.owner('harrisonrichard.eth')
eth0881=	ns.owner('lerichard.eth')
eth0882=	ns.owner('richarddrahcir.eth')
eth0883=	ns.owner('richardmercado.eth')
eth0884=	ns.owner('richardkolecani.eth')
eth0885=	ns.owner('superrichard.eth')
eth0886=	ns.owner('richardcore.eth')
eth0887=	ns.owner('richardgrenell.eth')
eth0888=	ns.owner('grandparichard.eth')
eth0889=	ns.owner('bryanjonesrichardson.eth')
eth0890=	ns.owner('richardmarx.eth')
eth0891=	ns.owner('richardheartbankless.eth')
eth0892=	ns.owner('richardmaxi.eth')
eth0893=	ns.owner('🍆richard.eth')
eth0894=	ns.owner('richard118.eth')
eth0895=	ns.owner('richard09.eth')
eth0896=	ns.owner('letsfuckingrichard.eth')
eth0897=	ns.owner('whyrichard.eth')
eth0898=	ns.owner('jordanrichards.eth')
eth0899=	ns.owner('richardmuirhead.eth')
eth0900=	ns.owner('saltyrichard.eth')
eth0901=	ns.owner('richardwang.eth')
eth0902=	ns.owner('jackrichards.eth')
eth0903=	ns.owner('richardhatch.eth')
eth0904=	ns.owner('richardlees.eth')
eth0905=	ns.owner('restorichard.eth')
eth0906=	ns.owner('whiskeyrichard.eth')
eth0907=	ns.owner('richard3rd.eth')
eth0908=	ns.owner('churchofrichard.eth')
eth0909=	ns.owner('richardloeser.eth')
eth0910=	ns.owner('richardthelionheart.eth')
eth0911=	ns.owner('richard365.eth')
eth0912=	ns.owner('richardise.eth')
eth0913=	ns.owner('richardkarnnft.eth')
eth0914=	ns.owner('richard81.eth')
eth0915=	ns.owner('richardhaggarty.eth')
eth0916=	ns.owner('richardsonlending.eth')
eth0917=	ns.owner('dr-richard.eth')
eth0918=	ns.owner('richardjunior.eth')
eth0919=	ns.owner('richardflint.eth')
eth0920=	ns.owner('richardwho.eth')
eth0921=	ns.owner('longrichard.eth')
eth0922=	ns.owner('og-richard.eth')
eth0923=	ns.owner('richardkain.eth')
eth0924=	ns.owner('richardxl.eth')
eth0925=	ns.owner('worldofrichard.eth')
eth0926=	ns.owner('bryanrichardson.eth')
eth0927=	ns.owner('bigrichard.eth')
eth0928=	ns.owner('richardcabral.eth')
eth0929=	ns.owner('youngrichard.eth')
eth0930=	ns.owner('pcrichard.eth')
eth0931=	ns.owner('richard005.eth')
eth0932=	ns.owner('richardthames.eth')
eth0933=	ns.owner('richardwad.eth')
eth0934=	ns.owner('sharearichard.eth')
eth0935=	ns.owner('richardhughes.eth')
eth0936=	ns.owner('kingrichard.eth')
eth0937=	ns.owner('richard507.eth')
eth0938=	ns.owner('gayrichard.eth')
eth0939=	ns.owner('richardblumenthal.eth')
eth0940=	ns.owner('hugerichard.eth')
eth0941=	ns.owner('richard43.eth')
eth0942=	ns.owner('richard46.eth')
eth0943=	ns.owner('richardt.eth')
eth0944=	ns.owner('richard94.eth')
eth0945=	ns.owner('richardheartpls.eth')
eth0946=	ns.owner('iamtherichard.eth')
eth0947=	ns.owner('richardat.eth')
eth0948=	ns.owner('byrichard.eth')
eth0949=	ns.owner('richardhagen.eth')
eth0950=	ns.owner('richardcorman.eth')
eth0951=	ns.owner('jakerichardson.eth')
eth0952=	ns.owner('richardgatz.eth')
eth0953=	ns.owner('djrichard.eth')
eth0954=	ns.owner('mcrichard.eth')
eth0955=	ns.owner('richardlarocque.eth')
eth0956=	ns.owner('adrianrichardson.eth')
eth0957=	ns.owner('richard408.eth')
eth0958=	ns.owner('shadyrichard.eth')
eth0959=	ns.owner('jrichards.eth')
eth0960=	ns.owner('rrichard.eth')
eth0961=	ns.owner('richardnehring.eth')
eth0962=	ns.owner('richard702.eth')
eth0963=	ns.owner('poorrichardclub.eth')
eth0964=	ns.owner('richard987.eth')
eth0965=	ns.owner('richardgreen.eth')
eth0966=	ns.owner('richard-branson.eth')
eth0967=	ns.owner('richardmillewatches.eth')
eth0968=	ns.owner('vote4richard.eth')
eth0969=	ns.owner('richardtip.eth')
eth0970=	ns.owner('richard831.eth')
eth0971=	ns.owner('stiffrichard.eth')
eth0972=	ns.owner('richardofficial.eth')
eth0973=	ns.owner('richardmiller.eth')
eth0974=	ns.owner('thisisrichard.eth')
eth0975=	ns.owner('richard-1.eth')
eth0976=	ns.owner('richard4.eth')
eth0977=	ns.owner('richards.eth')
eth0978=	ns.owner('richard714.eth')
eth0979=	ns.owner('richardzoolander.eth')
eth0980=	ns.owner('richard18.eth')
eth0981=	ns.owner('420richard.eth')
eth0982=	ns.owner('richarddeberry.eth')
eth0983=	ns.owner('richard39.eth')
eth0984=	ns.owner('richard98.eth')
eth0985=	ns.owner('richardkerr.eth')
eth0986=	ns.owner('richardlease.eth')
eth0987=	ns.owner('msrichard.eth')
eth0988=	ns.owner('richrichards.eth')
eth0989=	ns.owner('punk-richard.eth')
eth0990=	ns.owner('deadrichard.eth')
eth0991=	ns.owner('properrichard.eth')
eth0992=	ns.owner('richardting.eth')
eth0993=	ns.owner('richardjagger.eth')
eth0994=	ns.owner('richard38.eth')
eth0995=	ns.owner('realrichard.eth')
eth0996=	ns.owner('theonlyrichard.eth')
eth0997=	ns.owner('richard105.eth')
eth0998=	ns.owner('richardwu.eth')
eth0999=	ns.owner('richard122.eth')
eth01000=	ns.owner('whosrichard.eth')
eth01001=	ns.owner('stankyrichard.eth')
eth01002=	ns.owner('blackrichard.eth')
eth01003=	ns.owner('richard64.eth')
eth01004=	ns.owner('richard74.eth')
eth01005=	ns.owner('richard5.eth')
eth01006=	ns.owner('richard73.eth')
eth01007=	ns.owner('richardschwartz.eth')
eth01008=	ns.owner('richard07.eth')
eth01009=	ns.owner('richardmdown.eth')
eth01010=	ns.owner('richard115.eth')
eth01011=	ns.owner('richardverschoor.eth')
eth01012=	ns.owner('morphyrichards.eth')
eth01013=	ns.owner('heyrichard.eth')
eth01014=	ns.owner('2girls1richard.eth')
eth01015=	ns.owner('itsrichardswallet.eth')
eth01016=	ns.owner('richardtease.eth')
eth01017=	ns.owner('richardbrener.eth')
eth01018=	ns.owner('richardbutt.eth')
eth01019=	ns.owner('richardsandoval.eth')
eth01020=	ns.owner('web3richard.eth')
eth01021=	ns.owner('richardqiangdongliu.eth')
eth01022=	ns.owner('richardhublot.eth')
eth01023=	ns.owner('richard541.eth')
eth01024=	ns.owner('richard119.eth')
eth01025=	ns.owner('richierichardson.eth')
eth01026=	ns.owner('richard92.eth')
eth01027=	ns.owner('aperichard.eth')
eth01028=	ns.owner('darenrichardson.eth')
eth01029=	ns.owner('richardk.eth')
eth01030=	ns.owner('richardburton.eth')
eth01031=	ns.owner('richardtao.eth')
eth01032=	ns.owner('richard969.eth')
eth01033=	ns.owner('richardfunston.eth')
eth01034=	ns.owner('richardherbert.eth')
eth01035=	ns.owner('drrichards.eth')
eth01036=	ns.owner('docrichard.eth')
eth01037=	ns.owner('richarddavis.eth')
eth01038=	ns.owner('richardjohnson.eth')
eth01039=	ns.owner('i❤richard.eth')
eth01040=	ns.owner('richardl.eth')
eth01041=	ns.owner('deeprichard.eth')
eth01042=	ns.owner('richardv.eth')
eth01043=	ns.owner('swinginrichard.eth')
eth01044=	ns.owner('richardbollinger.eth')
eth01045=	ns.owner('therealrichard.eth')
eth01046=	ns.owner('colrichard.eth')
eth01047=	ns.owner('richard84.eth')
eth01048=	ns.owner('richardens.eth')
eth01049=	ns.owner('richard415.eth')
eth01050=	ns.owner('richardhead.eth')
eth01051=	ns.owner('sansrichard.eth')
eth01052=	ns.owner('captrichard.eth')
eth01053=	ns.owner('🔥richard🔥.eth')
eth01054=	ns.owner('richard100.eth')
eth01055=	ns.owner('richardlord.eth')
eth01056=	ns.owner('richardboomin.eth')
eth01057=	ns.owner('👑richard.eth')
eth01058=	ns.owner('captainrichard.eth')
eth01059=	ns.owner('runningrichard.eth')
eth01060=	ns.owner('richard30.eth')
eth01061=	ns.owner('richardpark.eth')
eth01062=	ns.owner('richardizard.eth')
eth01063=	ns.owner('richardshoeman.eth')
eth01064=	ns.owner('suckmyrichard.eth')
eth01065=	ns.owner('buddyrichard.eth')
eth01066=	ns.owner('richardsdick.eth')
eth01067=	ns.owner('mattrichardson.eth')
eth01068=	ns.owner('richardlxix.eth')
eth01069=	ns.owner('richardstallman.eth')
eth01070=	ns.owner('richardental.eth')
eth01071=	ns.owner('fatrichard.eth')
eth01072=	ns.owner('richardulicky.eth')
eth01073=	ns.owner('richard72.eth')
eth01074=	ns.owner('reedrichards.eth')
eth01075=	ns.owner('richardp.eth')
eth01076=	ns.owner('richard54.eth')
eth01077=	ns.owner('richardsmith.eth')
eth01078=	ns.owner('gmrichard.eth')
eth01079=	ns.owner('richard786.eth')
eth01080=	ns.owner('richard506.eth')
eth01081=	ns.owner('uniquerichard.eth')
eth01082=	ns.owner('richard314159265359.eth')
eth01083=	ns.owner('fuckerichard.eth')
eth01084=	ns.owner('richarded.eth')
eth01085=	ns.owner('iloverichard.eth')
eth01086=	ns.owner('richard104.eth')
eth01087=	ns.owner('richard80.eth')
eth01088=	ns.owner('itsrichard.eth')
eth01089=	ns.owner('richardwfrank.eth')
eth01090=	ns.owner('teamrichard.eth')
eth01091=	ns.owner('richard78.eth')
eth01092=	ns.owner('richardmilledealer.eth')
eth01093=	ns.owner('jesuisrichard.eth')
eth01094=	ns.owner('richardzhu.eth')
eth01095=	ns.owner('richard300.eth')
eth01096=	ns.owner('richardyoung.eth')
eth01097=	ns.owner('richardskywalker.eth')
eth01098=	ns.owner('richardbachman.eth')
eth01099=	ns.owner('richard76.eth')
eth01100=	ns.owner('richard0000.eth')
eth01101=	ns.owner('richard🇺🇸.eth')
eth01102=	ns.owner('richardplepler.eth')
eth01103=	ns.owner('richardh.eth')
eth01104=	ns.owner('erichard.eth')
eth01105=	ns.owner('richardlehane.eth')
eth01106=	ns.owner('richardjames.eth')
eth01107=	ns.owner('richardmaroun.eth')
eth01108=	ns.owner('richard67.eth')
eth01109=	ns.owner('richardiii.eth')
eth01110=	ns.owner('wrappedrichard.eth')
eth01111=	ns.owner('imrichardbiatch.eth')
eth01112=	ns.owner('richardunderwood.eth')
eth01113=	ns.owner('patrickrichards.eth')
eth01114=	ns.owner('richard🧀.eth')
eth01115=	ns.owner('richard-anderson.eth')
eth01116=	ns.owner('onlyrichards.eth')
eth01117=	ns.owner('franklinrichards.eth')
eth01118=	ns.owner('richardchen.eth')
eth01119=	ns.owner('dontbearichard.eth')
eth01120=	ns.owner('8-richard-0.eth')
eth01121=	ns.owner('richard425.eth')
eth01122=	ns.owner('richardpryor.eth')
eth01123=	ns.owner('smolrichard.eth')
eth01124=	ns.owner('richard99.eth')
eth01125=	ns.owner('richardstreet.eth')
eth01126=	ns.owner('richardsoncounty.eth')
eth01127=	ns.owner('richard876.eth')
eth01128=	ns.owner('richardsanders.eth')
eth01129=	ns.owner('richardstarkey.eth')
eth01130=	ns.owner('richard00.eth')
eth01131=	ns.owner('richardquinn.eth')
eth01132=	ns.owner('1strichard.eth')
eth01133=	ns.owner('fuckerrichard.eth')
eth01134=	ns.owner('richardlittlewood.eth')
eth01135=	ns.owner('richard08.eth')
eth01136=	ns.owner('ape-richard.eth')
eth01137=	ns.owner('richardlin.eth')
eth01138=	ns.owner('bigandrichard.eth')
eth01139=	ns.owner('jemappellerichard.eth')
eth01140=	ns.owner('cgrichard.eth')
eth01141=	ns.owner('richardly.eth')
eth01142=	ns.owner('richard718.eth')
eth01143=	ns.owner('callmerichard.eth')
eth01144=	ns.owner('dougrichard.eth')
eth01145=	ns.owner('richardsrainwater.eth')
eth01146=	ns.owner('chrisrichards.eth')
eth01147=	ns.owner('richardscarry.eth')
eth01148=	ns.owner('richardpic.eth')
eth01149=	ns.owner('richardyuen.eth')
eth01150=	ns.owner('richard65.eth')
eth01151=	ns.owner('thickrichard.eth')
eth01152=	ns.owner('richardofengland.eth')
eth01153=	ns.owner('richardofens.eth')
eth01154=	ns.owner('richardgarciaofficial.eth')
eth01155=	ns.owner('richard53.eth')
eth01156=	ns.owner('richard800.eth')
eth01157=	ns.owner('rektrichard.eth')
eth01158=	ns.owner('richardchild.eth')
eth01159=	ns.owner('missrichard.eth')
eth01160=	ns.owner('richardigm.eth')
eth01161=	ns.owner('richard20.eth')
eth01162=	ns.owner('richardvonpepe.eth')
eth01163=	ns.owner('yorichard.eth')
eth01164=	ns.owner('richardhorrocks.eth')
eth01165=	ns.owner('ultrarichard.eth')
eth01166=	ns.owner('richard510.eth')
eth01167=	ns.owner('richard505.eth')
eth01168=	ns.owner('richardserra.eth')
eth01169=	ns.owner('richardnfts.eth')
eth01170=	ns.owner('richardao.eth')
eth01171=	ns.owner('mainrichard.eth')
eth01172=	ns.owner('richardkho.eth')
eth01173=	ns.owner('richarddreyfuss.eth')
eth01174=	ns.owner('richardbandler.eth')
eth01175=	ns.owner('pcrichardandson.eth')
eth01176=	ns.owner('davidrichards.eth')
eth01177=	ns.owner('chiefrichard.eth')
eth01178=	ns.owner('cplrichard.eth')
eth01179=	ns.owner('richarddeananderson.eth')
eth01180=	ns.owner('richardfarleigh.eth')
eth01181=	ns.owner('circumcisedrichard.eth')
eth01182=	ns.owner('whothefuckisrichard.eth')
eth01183=	ns.owner('richardsr.eth')
eth01184=	ns.owner('richard3.eth')
eth01185=	ns.owner('robotrichard.eth')
eth01186=	ns.owner('richard321.eth')
eth01187=	ns.owner('ltrichard.eth')
eth01188=	ns.owner('richardallen.eth')
eth01189=	ns.owner('danielrichard.eth')
eth01190=	ns.owner('richard36.eth')
eth01191=	ns.owner('richardkclub.eth')
eth01192=	ns.owner('richardvan.eth')
eth01193=	ns.owner('richardthanyou.eth')
eth01194=	ns.owner('richardlearoyd.eth')
eth01195=	ns.owner('0xrichardson.eth')
eth01196=	ns.owner('richardmillevault.eth')
eth01197=	ns.owner('ethrichard.eth')
eth01198=	ns.owner('progressiverichard.eth')
eth01199=	ns.owner('richardlife.eth')
eth01200=	ns.owner('prettyrichard.eth')
eth01201=	ns.owner('shutuprichard.eth')
eth01202=	ns.owner('uncircumcisedrichard.eth')
eth01203=	ns.owner('6richard9.eth')
eth01204=	ns.owner('richard42069.eth')
eth01205=	ns.owner('anthonyrichardson.eth')
eth01206=	ns.owner('moby-richard.eth')
eth01207=	ns.owner('bankofrichard.eth')
eth01208=	ns.owner('weareallrichard.eth')
eth01209=	ns.owner('richardswol.eth')
eth01210=	ns.owner('dougrichardco.eth')
eth01211=	ns.owner('richardzack.eth')
eth01212=	ns.owner('eddierichard.eth')
eth01213=	ns.owner('richardbird.eth')
eth01214=	ns.owner('richard420.eth')
eth01215=	ns.owner('richardfucks.eth')
eth01216=	ns.owner('richardwidmark.eth')
eth01217=	ns.owner('richard907.eth')
eth01218=	ns.owner('richardstrauss.eth')
eth01219=	ns.owner('richardpickett.eth')
eth01220=	ns.owner('richard05.eth')
eth01221=	ns.owner('richardmooney.eth')
eth01222=	ns.owner('richard66.eth')
eth01223=	ns.owner('jacksonrichardson.eth')
eth01224=	ns.owner('richard9.eth')
eth01225=	ns.owner('bossrichard.eth')
eth01226=	ns.owner('richard10.eth')
eth01227=	ns.owner('darkrichard.eth')
eth01228=	ns.owner('lord-richard.eth')
eth01229=	ns.owner('richardprince.eth')
eth01230=	ns.owner('richardheinzl.eth')
eth01231=	ns.owner('richardj.eth')
eth01232=	ns.owner('richardsondigital.eth')
eth01233=	ns.owner('richard79.eth')
eth01234=	ns.owner('dotrichard.eth')
eth01235=	ns.owner('richardstokoe.eth')
eth01236=	ns.owner('richardramirez.eth')
eth01237=	ns.owner('richardclub.eth')
eth01238=	ns.owner('richardpaulhau.eth')
eth01239=	ns.owner('richardzhang.eth')
eth01240=	ns.owner('floppyrichard.eth')
eth01241=	ns.owner('richard888.eth')
eth01242=	ns.owner('mcrichards.eth')
eth01243=	ns.owner('richard516.eth')
eth01244=	ns.owner('richardbrown.eth')
eth01245=	ns.owner('2richard.eth')
eth01246=	ns.owner('tinyrichard.eth')
eth01247=	ns.owner('richardwong.eth')
eth01248=	ns.owner('richard001.eth')
eth01249=	ns.owner('richard-bullrun.eth')
eth01250=	ns.owner('richardrichards.eth')
eth01251=	ns.owner('richardroad.eth')
eth01252=	ns.owner('richardheartplusbankless.eth')
eth01253=	ns.owner('richarddick.eth')
eth01254=	ns.owner('50richard.eth')
eth01255=	ns.owner('richardburr.eth')
eth01256=	ns.owner('richardcrooks.eth')
eth01257=	ns.owner('richard69-420.eth')
eth01258=	ns.owner('lilrichard.eth')
eth01259=	ns.owner('richyrichard.eth')
eth01260=	ns.owner('richardguan.eth')
eth01261=	ns.owner('richard360.eth')

print(eth01)
print(eth02)
print(eth03)
print(eth04)
print(eth05)
print(eth06)
print(eth07)
print(eth08)
print(eth09)
print(eth010)
print(eth011)
print(eth012)
print(eth013)
print(eth014)
print(eth015)
print(eth016)
print(eth017)
print(eth018)
print(eth019)
print(eth020)
print(eth021)
print(eth022)
print(eth023)
print(eth024)
print(eth025)
print(eth026)
print(eth027)
print(eth028)
print(eth029)
print(eth030)
print(eth031)
print(eth032)
print(eth033)
print(eth034)
print(eth035)
print(eth036)
print(eth037)
print(eth038)
print(eth039)
print(eth040)
print(eth041)
print(eth042)
print(eth043)
print(eth044)
print(eth045)
print(eth046)
print(eth047)
print(eth048)
print(eth049)
print(eth050)
print(eth051)
print(eth052)
print(eth053)
print(eth054)
print(eth055)
print(eth056)
print(eth057)
print(eth058)
print(eth059)
print(eth060)
print(eth061)
print(eth062)
print(eth063)
print(eth064)
print(eth065)
print(eth066)
print(eth067)
print(eth068)
print(eth069)
print(eth070)
print(eth071)
print(eth072)
print(eth073)
print(eth074)
print(eth075)
print(eth076)
print(eth077)
print(eth078)
print(eth079)
print(eth080)
print(eth081)
print(eth082)
print(eth083)
print(eth084)
print(eth085)
print(eth086)
print(eth087)
print(eth088)
print(eth089)
print(eth090)
print(eth091)
print(eth092)
print(eth093)
print(eth094)
print(eth095)
print(eth096)
print(eth097)
print(eth098)
print(eth099)
print(eth0100)
print(eth0101)
print(eth0102)
print(eth0103)
print(eth0104)
print(eth0105)
print(eth0106)
print(eth0107)
print(eth0108)
print(eth0109)
print(eth0110)
print(eth0111)
print(eth0112)
print(eth0113)
print(eth0114)
print(eth0115)
print(eth0116)
print(eth0117)
print(eth0118)
print(eth0119)
print(eth0120)
print(eth0121)
print(eth0122)
print(eth0123)
print(eth0124)
print(eth0125)
print(eth0126)
print(eth0127)
print(eth0128)
print(eth0129)
print(eth0130)
print(eth0131)
print(eth0132)
print(eth0133)
print(eth0134)
print(eth0135)
print(eth0136)
print(eth0137)
print(eth0138)
print(eth0139)
print(eth0140)
print(eth0141)
print(eth0142)
print(eth0143)
print(eth0144)
print(eth0145)
print(eth0146)
print(eth0147)
print(eth0148)
print(eth0149)
print(eth0150)
print(eth0151)
print(eth0152)
print(eth0153)
print(eth0154)
print(eth0155)
print(eth0156)
print(eth0157)
print(eth0158)
print(eth0159)
print(eth0160)
print(eth0161)
print(eth0162)
print(eth0163)
print(eth0164)
print(eth0165)
print(eth0166)
print(eth0167)
print(eth0168)
print(eth0169)
print(eth0170)
print(eth0171)
print(eth0172)
print(eth0173)
print(eth0174)
print(eth0175)
print(eth0176)
print(eth0177)
print(eth0178)
print(eth0179)
print(eth0180)
print(eth0181)
print(eth0182)
print(eth0183)
print(eth0184)
print(eth0185)
print(eth0186)
print(eth0187)
print(eth0188)
print(eth0189)
print(eth0190)
print(eth0191)
print(eth0192)
print(eth0193)
print(eth0194)
print(eth0195)
print(eth0196)
print(eth0197)
print(eth0198)
print(eth0199)
print(eth0200)
print(eth0201)
print(eth0202)
print(eth0203)
print(eth0204)
print(eth0205)
print(eth0206)
print(eth0207)
print(eth0208)
print(eth0209)
print(eth0210)
print(eth0211)
print(eth0212)
print(eth0213)
print(eth0214)
print(eth0215)
print(eth0216)
print(eth0217)
print(eth0218)
print(eth0219)
print(eth0220)
print(eth0221)
print(eth0222)
print(eth0223)
print(eth0224)
print(eth0225)
print(eth0226)
print(eth0227)
print(eth0228)
print(eth0229)
print(eth0230)
print(eth0231)
print(eth0232)
print(eth0233)
print(eth0234)
print(eth0235)
print(eth0236)
print(eth0237)
print(eth0238)
print(eth0239)
print(eth0240)
print(eth0241)
print(eth0242)
print(eth0243)
print(eth0244)
print(eth0245)
print(eth0246)
print(eth0247)
print(eth0248)
print(eth0249)
print(eth0250)
print(eth0251)
print(eth0252)
print(eth0253)
print(eth0254)
print(eth0255)
print(eth0256)
print(eth0257)
print(eth0258)
print(eth0259)
print(eth0260)
print(eth0261)
print(eth0262)
print(eth0263)
print(eth0264)
print(eth0265)
print(eth0266)
print(eth0267)
print(eth0268)
print(eth0269)
print(eth0270)
print(eth0271)
print(eth0272)
print(eth0273)
print(eth0274)
print(eth0275)
print(eth0276)
print(eth0277)
print(eth0278)
print(eth0279)
print(eth0280)
print(eth0281)
print(eth0282)
print(eth0283)
print(eth0284)
print(eth0285)
print(eth0286)
print(eth0287)
print(eth0288)
print(eth0289)
print(eth0290)
print(eth0291)
print(eth0292)
print(eth0293)
print(eth0294)
print(eth0295)
print(eth0296)
print(eth0297)
print(eth0298)
print(eth0299)
print(eth0300)
print(eth0301)
print(eth0302)
print(eth0303)
print(eth0304)
print(eth0305)
print(eth0306)
print(eth0307)
print(eth0308)
print(eth0309)
print(eth0310)
print(eth0311)
print(eth0312)
print(eth0313)
print(eth0314)
print(eth0315)
print(eth0316)
print(eth0317)
print(eth0318)
print(eth0319)
print(eth0320)
print(eth0321)
print(eth0322)
print(eth0323)
print(eth0324)
print(eth0325)
print(eth0326)
print(eth0327)
print(eth0328)
print(eth0329)
print(eth0330)
print(eth0331)
print(eth0332)
print(eth0333)
print(eth0334)
print(eth0335)
print(eth0336)
print(eth0337)
print(eth0338)
print(eth0339)
print(eth0340)
print(eth0341)
print(eth0342)
print(eth0343)
print(eth0344)
print(eth0345)
print(eth0346)
print(eth0347)
print(eth0348)
print(eth0349)
print(eth0350)
print(eth0351)
print(eth0352)
print(eth0353)
print(eth0354)
print(eth0355)
print(eth0356)
print(eth0357)
print(eth0358)
print(eth0359)
print(eth0360)
print(eth0361)
print(eth0362)
print(eth0363)
print(eth0364)
print(eth0365)
print(eth0366)
print(eth0367)
print(eth0368)
print(eth0369)
print(eth0370)
print(eth0371)
print(eth0372)
print(eth0373)
print(eth0374)
print(eth0375)
print(eth0376)
print(eth0377)
print(eth0378)
print(eth0379)
print(eth0380)
print(eth0381)
print(eth0382)
print(eth0383)
print(eth0384)
print(eth0385)
print(eth0386)
print(eth0387)
print(eth0388)
print(eth0389)
print(eth0390)
print(eth0391)
print(eth0392)
print(eth0393)
print(eth0394)
print(eth0395)
print(eth0396)
print(eth0397)
print(eth0398)
print(eth0399)
print(eth0400)
print(eth0401)
print(eth0402)
print(eth0403)
print(eth0404)
print(eth0405)
print(eth0406)
print(eth0407)
print(eth0408)
print(eth0409)
print(eth0410)
print(eth0411)
print(eth0412)
print(eth0413)
print(eth0414)
print(eth0415)
print(eth0416)
print(eth0417)
print(eth0418)
print(eth0419)
print(eth0420)
print(eth0421)
print(eth0422)
print(eth0423)
print(eth0424)
print(eth0425)
print(eth0426)
print(eth0427)
print(eth0428)
print(eth0429)
print(eth0430)
print(eth0431)
print(eth0432)
print(eth0433)
print(eth0434)
print(eth0435)
print(eth0436)
print(eth0437)
print(eth0438)
print(eth0439)
print(eth0440)
print(eth0441)
print(eth0442)
print(eth0443)
print(eth0444)
print(eth0445)
print(eth0446)
print(eth0447)
print(eth0448)
print(eth0449)
print(eth0450)
print(eth0451)
print(eth0452)
print(eth0453)
print(eth0454)
print(eth0455)
print(eth0456)
print(eth0457)
print(eth0458)
print(eth0459)
print(eth0460)
print(eth0461)
print(eth0462)
print(eth0463)
print(eth0464)
print(eth0465)
print(eth0466)
print(eth0467)
print(eth0468)
print(eth0469)
print(eth0470)
print(eth0471)
print(eth0472)
print(eth0473)
print(eth0474)
print(eth0475)
print(eth0476)
print(eth0477)
print(eth0478)
print(eth0479)
print(eth0480)
print(eth0481)
print(eth0482)
print(eth0483)
print(eth0484)
print(eth0485)
print(eth0486)
print(eth0487)
print(eth0488)
print(eth0489)
print(eth0490)
print(eth0491)
print(eth0492)
print(eth0493)
print(eth0494)
print(eth0495)
print(eth0496)
print(eth0497)
print(eth0498)
print(eth0499)
print(eth0500)
print(eth0501)
print(eth0502)
print(eth0503)
print(eth0504)
print(eth0505)
print(eth0506)
print(eth0507)
print(eth0508)
print(eth0509)
print(eth0510)
print(eth0511)
print(eth0512)
print(eth0513)
print(eth0514)
print(eth0515)
print(eth0516)
print(eth0517)
print(eth0518)
print(eth0519)
print(eth0520)
print(eth0521)
print(eth0522)
print(eth0523)
print(eth0524)
print(eth0525)
print(eth0526)
print(eth0527)
print(eth0528)
print(eth0529)
print(eth0530)
print(eth0531)
print(eth0532)
print(eth0533)
print(eth0534)
print(eth0535)
print(eth0536)
print(eth0537)
print(eth0538)
print(eth0539)
print(eth0540)
print(eth0541)
print(eth0542)
print(eth0543)
print(eth0544)
print(eth0545)
print(eth0546)
print(eth0547)
print(eth0548)
print(eth0549)
print(eth0550)
print(eth0551)
print(eth0552)
print(eth0553)
print(eth0554)
print(eth0555)
print(eth0556)
print(eth0557)
print(eth0558)
print(eth0559)
print(eth0560)
print(eth0561)
print(eth0562)
print(eth0563)
print(eth0564)
print(eth0565)
print(eth0566)
print(eth0567)
print(eth0568)
print(eth0569)
print(eth0570)
print(eth0571)
print(eth0572)
print(eth0573)
print(eth0574)
print(eth0575)
print(eth0576)
print(eth0577)
print(eth0578)
print(eth0579)
print(eth0580)
print(eth0581)
print(eth0582)
print(eth0583)
print(eth0584)
print(eth0585)
print(eth0586)
print(eth0587)
print(eth0588)
print(eth0589)
print(eth0590)
print(eth0591)
print(eth0592)
print(eth0593)
print(eth0594)
print(eth0595)
print(eth0596)
print(eth0597)
print(eth0598)
print(eth0599)
print(eth0600)
print(eth0601)
print(eth0602)
print(eth0603)
print(eth0604)
print(eth0605)
print(eth0606)
print(eth0607)
print(eth0608)
print(eth0609)
print(eth0610)
print(eth0611)
print(eth0612)
print(eth0613)
print(eth0614)
print(eth0615)
print(eth0616)
print(eth0617)
print(eth0618)
print(eth0619)
print(eth0620)
print(eth0621)
print(eth0622)
print(eth0623)
print(eth0624)
print(eth0625)
print(eth0626)
print(eth0627)
print(eth0628)
print(eth0629)
print(eth0630)
print(eth0631)
print(eth0632)
print(eth0633)
print(eth0634)
print(eth0635)
print(eth0636)
print(eth0637)
print(eth0638)
print(eth0639)
print(eth0640)
print(eth0641)
print(eth0642)
print(eth0643)
print(eth0644)
print(eth0645)
print(eth0646)
print(eth0647)
print(eth0648)
print(eth0649)
print(eth0650)
print(eth0651)
print(eth0652)
print(eth0653)
print(eth0654)
print(eth0655)
print(eth0656)
print(eth0657)
print(eth0658)
print(eth0659)
print(eth0660)
print(eth0661)
print(eth0662)
print(eth0663)
print(eth0664)
print(eth0665)
print(eth0666)
print(eth0667)
print(eth0668)
print(eth0669)
print(eth0670)
print(eth0671)
print(eth0672)
print(eth0673)
print(eth0674)
print(eth0675)
print(eth0676)
print(eth0677)
print(eth0678)
print(eth0679)
print(eth0680)
print(eth0681)
print(eth0682)
print(eth0683)
print(eth0684)
print(eth0685)
print(eth0686)
print(eth0687)
print(eth0688)
print(eth0689)
print(eth0690)
print(eth0691)
print(eth0692)
print(eth0693)
print(eth0694)
print(eth0695)
print(eth0696)
print(eth0697)
print(eth0698)
print(eth0699)
print(eth0700)
print(eth0701)
print(eth0702)
print(eth0703)
print(eth0704)
print(eth0705)
print(eth0706)
print(eth0707)
print(eth0708)
print(eth0709)
print(eth0710)
print(eth0711)
print(eth0712)
print(eth0713)
print(eth0714)
print(eth0715)
print(eth0716)
print(eth0717)
print(eth0718)
print(eth0719)
print(eth0720)
print(eth0721)
print(eth0722)
print(eth0723)
print(eth0724)
print(eth0725)
print(eth0726)
print(eth0727)
print(eth0728)
print(eth0729)
print(eth0730)
print(eth0731)
print(eth0732)
print(eth0733)
print(eth0734)
print(eth0735)
print(eth0736)
print(eth0737)
print(eth0738)
print(eth0739)
print(eth0740)
print(eth0741)
print(eth0742)
print(eth0743)
print(eth0744)
print(eth0745)
print(eth0746)
print(eth0747)
print(eth0748)
print(eth0749)
print(eth0750)
print(eth0751)
print(eth0752)
print(eth0753)
print(eth0754)
print(eth0755)
print(eth0756)
print(eth0757)
print(eth0758)
print(eth0759)
print(eth0760)
print(eth0761)
print(eth0762)
print(eth0763)
print(eth0764)
print(eth0765)
print(eth0766)
print(eth0767)
print(eth0768)
print(eth0769)
print(eth0770)
print(eth0771)
print(eth0772)
print(eth0773)
print(eth0774)
print(eth0775)
print(eth0776)
print(eth0777)
print(eth0778)
print(eth0779)
print(eth0780)
print(eth0781)
print(eth0782)
print(eth0783)
print(eth0784)
print(eth0785)
print(eth0786)
print(eth0787)
print(eth0788)
print(eth0789)
print(eth0790)
print(eth0791)
print(eth0792)
print(eth0793)
print(eth0794)
print(eth0795)
print(eth0796)
print(eth0797)
print(eth0798)
print(eth0799)
print(eth0800)
print(eth0801)
print(eth0802)
print(eth0803)
print(eth0804)
print(eth0805)
print(eth0806)
print(eth0807)
print(eth0808)
print(eth0809)
print(eth0810)
print(eth0811)
print(eth0812)
print(eth0813)
print(eth0814)
print(eth0815)
print(eth0816)
print(eth0817)
print(eth0818)
print(eth0819)
print(eth0820)
print(eth0821)
print(eth0822)
print(eth0823)
print(eth0824)
print(eth0825)
print(eth0826)
print(eth0827)
print(eth0828)
print(eth0829)
print(eth0830)
print(eth0831)
print(eth0832)
print(eth0833)
print(eth0834)
print(eth0835)
print(eth0836)
print(eth0837)
print(eth0838)
print(eth0839)
print(eth0840)
print(eth0841)
print(eth0842)
print(eth0843)
print(eth0844)
print(eth0845)
print(eth0846)
print(eth0847)
print(eth0848)
print(eth0849)
print(eth0850)
print(eth0851)
print(eth0852)
print(eth0853)
print(eth0854)
print(eth0855)
print(eth0856)
print(eth0857)
print(eth0858)
print(eth0859)
print(eth0860)
print(eth0861)
print(eth0862)
print(eth0863)
print(eth0864)
print(eth0865)
print(eth0866)
print(eth0867)
print(eth0868)
print(eth0869)
print(eth0870)
print(eth0871)
print(eth0872)
print(eth0873)
print(eth0874)
print(eth0875)
print(eth0876)
print(eth0877)
print(eth0878)
print(eth0879)
print(eth0880)
print(eth0881)
print(eth0882)
print(eth0883)
print(eth0884)
print(eth0885)
print(eth0886)
print(eth0887)
print(eth0888)
print(eth0889)
print(eth0890)
print(eth0891)
print(eth0892)
print(eth0893)
print(eth0894)
print(eth0895)
print(eth0896)
print(eth0897)
print(eth0898)
print(eth0899)
print(eth0900)
print(eth0901)
print(eth0902)
print(eth0903)
print(eth0904)
print(eth0905)
print(eth0906)
print(eth0907)
print(eth0908)
print(eth0909)
print(eth0910)
print(eth0911)
print(eth0912)
print(eth0913)
print(eth0914)
print(eth0915)
print(eth0916)
print(eth0917)
print(eth0918)
print(eth0919)
print(eth0920)
print(eth0921)
print(eth0922)
print(eth0923)
print(eth0924)
print(eth0925)
print(eth0926)
print(eth0927)
print(eth0928)
print(eth0929)
print(eth0930)
print(eth0931)
print(eth0932)
print(eth0933)
print(eth0934)
print(eth0935)
print(eth0936)
print(eth0937)
print(eth0938)
print(eth0939)
print(eth0940)
print(eth0941)
print(eth0942)
print(eth0943)
print(eth0944)
print(eth0945)
print(eth0946)
print(eth0947)
print(eth0948)
print(eth0949)
print(eth0950)
print(eth0951)
print(eth0952)
print(eth0953)
print(eth0954)
print(eth0955)
print(eth0956)
print(eth0957)
print(eth0958)
print(eth0959)
print(eth0960)
print(eth0961)
print(eth0962)
print(eth0963)
print(eth0964)
print(eth0965)
print(eth0966)
print(eth0967)
print(eth0968)
print(eth0969)
print(eth0970)
print(eth0971)
print(eth0972)
print(eth0973)
print(eth0974)
print(eth0975)
print(eth0976)
print(eth0977)
print(eth0978)
print(eth0979)
print(eth0980)
print(eth0981)
print(eth0982)
print(eth0983)
print(eth0984)
print(eth0985)
print(eth0986)
print(eth0987)
print(eth0988)
print(eth0989)
print(eth0990)
print(eth0991)
print(eth0992)
print(eth0993)
print(eth0994)
print(eth0995)
print(eth0996)
print(eth0997)
print(eth0998)
print(eth0999)
print(eth01000)
print(eth01001)
print(eth01002)
print(eth01003)
print(eth01004)
print(eth01005)
print(eth01006)
print(eth01007)
print(eth01008)
print(eth01009)
print(eth01010)
print(eth01011)
print(eth01012)
print(eth01013)
print(eth01014)
print(eth01015)
print(eth01016)
print(eth01017)
print(eth01018)
print(eth01019)
print(eth01020)
print(eth01021)
print(eth01022)
print(eth01023)
print(eth01024)
print(eth01025)
print(eth01026)
print(eth01027)
print(eth01028)
print(eth01029)
print(eth01030)
print(eth01031)
print(eth01032)
print(eth01033)
print(eth01034)
print(eth01035)
print(eth01036)
print(eth01037)
print(eth01038)
print(eth01039)
print(eth01040)
print(eth01041)
print(eth01042)
print(eth01043)
print(eth01044)
print(eth01045)
print(eth01046)
print(eth01047)
print(eth01048)
print(eth01049)
print(eth01050)
print(eth01051)
print(eth01052)
print(eth01053)
print(eth01054)
print(eth01055)
print(eth01056)
print(eth01057)
print(eth01058)
print(eth01059)
print(eth01060)
print(eth01061)
print(eth01062)
print(eth01063)
print(eth01064)
print(eth01065)
print(eth01066)
print(eth01067)
print(eth01068)
print(eth01069)
print(eth01070)
print(eth01071)
print(eth01072)
print(eth01073)
print(eth01074)
print(eth01075)
print(eth01076)
print(eth01077)
print(eth01078)
print(eth01079)
print(eth01080)
print(eth01081)
print(eth01082)
print(eth01083)
print(eth01084)
print(eth01085)
print(eth01086)
print(eth01087)
print(eth01088)
print(eth01089)
print(eth01090)
print(eth01091)
print(eth01092)
print(eth01093)
print(eth01094)
print(eth01095)
print(eth01096)
print(eth01097)
print(eth01098)
print(eth01099)
print(eth01100)
print(eth01101)
print(eth01102)
print(eth01103)
print(eth01104)
print(eth01105)
print(eth01106)
print(eth01107)
print(eth01108)
print(eth01109)
print(eth01110)
print(eth01111)
print(eth01112)
print(eth01113)
print(eth01114)
print(eth01115)
print(eth01116)
print(eth01117)
print(eth01118)
print(eth01119)
print(eth01120)
print(eth01121)
print(eth01122)
print(eth01123)
print(eth01124)
print(eth01125)
print(eth01126)
print(eth01127)
print(eth01128)
print(eth01129)
print(eth01130)
print(eth01131)
print(eth01132)
print(eth01133)
print(eth01134)
print(eth01135)
print(eth01136)
print(eth01137)
print(eth01138)
print(eth01139)
print(eth01140)
print(eth01141)
print(eth01142)
print(eth01143)
print(eth01144)
print(eth01145)
print(eth01146)
print(eth01147)
print(eth01148)
print(eth01149)
print(eth01150)
print(eth01151)
print(eth01152)
print(eth01153)
print(eth01154)
print(eth01155)
print(eth01156)
print(eth01157)
print(eth01158)
print(eth01159)
print(eth01160)
print(eth01161)
print(eth01162)
print(eth01163)
print(eth01164)
print(eth01165)
print(eth01166)
print(eth01167)
print(eth01168)
print(eth01169)
print(eth01170)
print(eth01171)
print(eth01172)
print(eth01173)
print(eth01174)
print(eth01175)
print(eth01176)
print(eth01177)
print(eth01178)
print(eth01179)
print(eth01180)
print(eth01181)
print(eth01182)
print(eth01183)
print(eth01184)
print(eth01185)
print(eth01186)
print(eth01187)
print(eth01188)
print(eth01189)
print(eth01190)
print(eth01191)
print(eth01192)
print(eth01193)
print(eth01194)
print(eth01195)
print(eth01196)
print(eth01197)
print(eth01198)
print(eth01199)
print(eth01200)
print(eth01201)
print(eth01202)
print(eth01203)
print(eth01204)
print(eth01205)
print(eth01206)
print(eth01207)
print(eth01208)
print(eth01209)
print(eth01210)
print(eth01211)
print(eth01212)
print(eth01213)
print(eth01214)
print(eth01215)
print(eth01216)
print(eth01217)
print(eth01218)
print(eth01219)
print(eth01220)
print(eth01221)
print(eth01222)
print(eth01223)
print(eth01224)
print(eth01225)
print(eth01226)
print(eth01227)
print(eth01228)
print(eth01229)
print(eth01230)
print(eth01231)
print(eth01232)
print(eth01233)
print(eth01234)
print(eth01235)
print(eth01236)
print(eth01237)
print(eth01238)
print(eth01239)
print(eth01240)
print(eth01241)
print(eth01242)
print(eth01243)
print(eth01244)
print(eth01245)
print(eth01246)
print(eth01247)
print(eth01248)
print(eth01249)
print(eth01250)
print(eth01251)
print(eth01252)
print(eth01253)
print(eth01254)
print(eth01255)
print(eth01256)
print(eth01257)
print(eth01258)
print(eth01259)
print(eth01260)
print(eth01261)
# Out:
# 0x43e7D6CF833733b6F7e0c1E4AC5b7FB2A4570807
# 0xe9A4BEC6efAD5ce161b44670af674c2D6daF0793
# 0x7a513A9B13Ca9eC6C2C49d1Bba085BfF0065413f
# 0x650813BA759E0f30b4CDCdBb0FbE5ce58940FEf9
# 0xB38df0667c7127149c47786131E3833Cb8c076f5
# 0xE5B23976d67d5752F9177a76AB4F5Bc20f4FBa83
# 0x73029536412d32449FB7135469368c65E3DBbE48
# 0x6053904B1643182F235DD8F1A91E851662d93D35
# 0xA4f0C25277Cc1226788AB58B4512551EB1944003
# 0xa2E87Bf4e4EdC28922736887772C351de5554b77
# 0x76B531FcE38Ee72c7CACC882D62502BC865dE3f2
# 0x967b0fc74C321070146Cb7e7B37381292c5ecf8e
# 0xfF6ddb157773197c31a834F6A294c7D0c0abc79F
# 0xc5B424aE1A47b4DE6960D17Fcb26e3f1B464f8A8
# 0xc6Cf0CfC68c445956F50697F734c3E73F9057AD5
# 0xB38df0667c7127149c47786131E3833Cb8c076f5
# 0xb55050FfF6c64f137C5975aFd296cf8435390AE6
# 0xEfe150ec0d2D4a42AFB5e48566Bf253343Fb70d9
# 0xf8bd714c20D09dC0902932e855d280ED457F9A52
# 0xA214384Fd96D0883A4E4c75036c2863f0F5995f5
# 0x98717560d065DbA4f8C259B9d079818489ad65C2
# 0xd71b74e73B7DEf499B6E2dADd8908EDC1E5a67CC
# ...
